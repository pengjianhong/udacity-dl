# %% [markdown]
# # 图像分类
#
# 在此项目中，你将对 [CIFAR-10 数据集](https://www.cs.toronto.edu/~kriz/cifar.html) 中的图片进行分类。该数据集包含飞机、猫狗和其他物体。你需要预处理这些图片，然后用所有样本训练一个卷积神经网络。图片需要标准化（normalized），标签需要采用 one-hot 编码。你需要应用所学的知识构建卷积的、最大池化（max pooling）、丢弃（dropout）和完全连接（fully connected）的层。最后，你需要在样本图片上看到神经网络的预测结果。
#
#
# ## 获取数据
#
# 请运行以下单元，以下载 [CIFAR-10 数据集（Python版）](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz)。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = './input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## 探索数据
#
# 该数据集分成了几部分／批次（batches），以免你的机器在计算时内存不足。CIFAR-10 数据集包含 5 个部分，名称分别为 `data_batch_1`、`data_batch_2`，以此类推。每个部分都包含以下某个类别的标签和图片：
#
# * 飞机
# * 汽车
# * 鸟类
# * 猫
# * 鹿
# * 狗
# * 青蛙
# * 马
# * 船只
# * 卡车
#
# 了解数据集也是对数据进行预测的必经步骤。你可以通过更改 `batch_id` 和 `sample_id` 探索下面的代码单元。`batch_id` 是数据集一个部分的 ID（1 到 5）。`sample_id` 是该部分中图片和标签对（label pair）的 ID。
#
# 问问你自己：“可能的标签有哪些？”、“图片数据的值范围是多少？”、“标签是按顺序排列，还是随机排列的？”。思考类似的问题，有助于你预处理数据，并使预测结果更准确。

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## 实现预处理函数
#
# ### 标准化
#
# 在下面的单元中，实现 `normalize` 函数，传入图片数据 `x`，并返回标准化 Numpy 数组。值应该在 0 到 1 的范围内（含 0 和 1）。返回对象应该和 `x` 的形状一样。

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    # so: 0-1 norm
    xmax = np.max(x)
    xmin = np.min(x)
    norm = (x - xmin)/(xmax - xmin)
    return norm


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot 编码
#
# 和之前的代码单元一样，你将为预处理实现一个函数。这次，你将实现 `one_hot_encode` 函数。输入，也就是 `x`，是一个标签列表。实现该函数，以返回为 one_hot 编码的 Numpy 数组的标签列表。标签的可能值为 0 到 9。每次调用 `one_hot_encode` 时，对于每个值，one_hot 编码函数应该返回相同的编码。确保将编码映射保存到该函数外面。
#
# 提示：不要重复发明轮子。

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    # 0: 1000_0000_00
    # 1: 0100_0000_00
    # x = [3,6.0,8]
    onehot = np.zeros((len(x),10),dtype=float)
    for index,label in enumerate(x):
        onehot[index][label] = 1
    return onehot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### 随机化数据
#
# 之前探索数据时，你已经了解到，样本的顺序是随机的。再随机化一次也不会有什么关系，但是对于这个数据集没有必要。

# %% [markdown]
# ## 预处理所有数据并保存
#
# 运行下方的代码单元，将预处理所有 CIFAR-10 数据，并保存到文件中。下面的代码还使用了 10% 的训练数据，用来验证。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，你可以从这里开始。预处理的数据已保存到本地。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %%
valid_features.dtype
# Out:
# dtype('float64')

# %%
valid_labels.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## 构建网络
#
# 对于该神经网络，你需要将每层都构建为一个函数。你看到的大部分代码都位于函数外面。要更全面地测试你的代码，我们需要你将每层放入一个函数中。这样使我们能够提供更好的反馈，并使用我们的统一测试检测简单的错误，然后再提交项目。
#
# >**注意**：如果你觉得每周很难抽出足够的时间学习这门课程，我们为此项目提供了一个小捷径。对于接下来的几个问题，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 程序包中的类来构建每个层级，但是“卷积和最大池化层级”部分的层级除外。TF Layers 和 Keras 及 TFLearn 层级类似，因此很容易学会。
#
# >但是，如果你想充分利用这门课程，请尝试自己解决所有问题，不使用 TF Layers 程序包中的任何类。你依然可以使用其他程序包中的类，这些类和你在 TF Layers 中的类名称是一样的！例如，你可以使用 TF Neural Network 版本的 `conv2d` 类 [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d)，而不是 TF Layers 版本的 `conv2d` 类 [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d)。
#
# 我们开始吧！
#
#
# ### 输入
#
# 神经网络需要读取图片数据、one-hot 编码标签和丢弃保留概率（dropout keep probability）。请实现以下函数：
#
# * 实现 `neural_net_image_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `image_shape` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "x" 命名
# * 实现 `neural_net_label_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `n_classes` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "y" 命名
# * 实现 `neural_net_keep_prob_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)，用于丢弃保留概率
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "keep_prob" 命名
#
# 这些名称将在项目结束时，用于加载保存的模型。
#
# 注意：TensorFlow 中的 `None` 表示形状可以是动态大小。

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    image_shape = (None,) + image_shape
    image = tf.placeholder(dtype=tf.float32,shape=image_shape,name="x")
    return image


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    label_shape = (None,n_classes)
    label = tf.placeholder(dtype=tf.float32,shape=label_shape,name="y")
    return label


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype=tf.float32,shape=None,name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### 卷积和最大池化层
#
# 卷积层级适合处理图片。对于此代码单元，你应该实现函数 `conv2d_maxpool` 以便应用卷积然后进行最大池化：
#
# * 使用 `conv_ksize`、`conv_num_outputs` 和 `x_tensor` 的形状创建权重（weight）和偏置（bias）。
# * 使用权重和 `conv_strides` 对 `x_tensor` 应用卷积。
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
# * 添加偏置
# * 向卷积中添加非线性激活（nonlinear activation）
# * 使用 `pool_ksize` 和 `pool_strides` 应用最大池化
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
#
# **注意**：对于**此层**，**请勿使用** [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers)，但是仍然可以使用 TensorFlow 的 [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) 包。对于所有**其他层**，你依然可以使用快捷方法。

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # conv2d
    conv2d_shape = conv_ksize + (x_tensor.get_shape().as_list()[-1],conv_num_outputs)
    conv2d_strides = (1,) + conv_strides + (1,)
    print("conv2d_shape: ", conv2d_shape)
    print("conv2d_strides: ", conv2d_strides)
    std = 0.1
    kernel = tf.Variable(tf.truncated_normal(shape=conv2d_shape,stddev=std,dtype=tf.float32))
    bias = tf.zeros(conv_num_outputs,dtype=tf.float32)
    conv2d = tf.nn.bias_add(tf.nn.conv2d(x_tensor,kernel,conv2d_strides,padding="SAME"),bias)
    activate = tf.nn.relu(conv2d)
    maxpool_ksize = (1,) + pool_ksize + (1,)
    maxpool_strides = (1,) + pool_strides + (1,)
    print("maxpool_ksize: ", maxpool_ksize)
    print("maxpool_strides: ", maxpool_strides)
    result = tf.nn.max_pool(activate,maxpool_ksize,maxpool_strides,padding="SAME")
    return result 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# conv2d_shape:  (2, 2, 5, 10)
# conv2d_strides:  (1, 4, 4, 1)
# maxpool_ksize:  (1, 2, 2, 1)
# maxpool_strides:  (1, 2, 2, 1)
# Tests Passed

# %% [markdown]
# ### 扁平化层
#
# 实现 `flatten` 函数，将 `x_tensor` 的维度从四维张量（4-D tensor）变成二维张量。输出应该是形状（*部分大小（Batch Size）*，*扁平化图片大小（Flattened Image Size）*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
from functools import reduce
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shapelist = x_tensor.get_shape().as_list()
    batchsize = shapelist[0]
    flatten_size = reduce(lambda x,y:x*y,shapelist[1:])
    reshape = (-1,flatten_size) # should write -1, not None
    print(reshape)
    return tf.reshape(x_tensor,shape=reshape)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# (-1, 1800)
# Tests Passed

# %% [markdown]
# ### 全连接层
#
# 实现 `fully_conn` 函数，以向 `x_tensor` 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    # after flatten process
    x_dim = x_tensor.get_shape().as_list()[1]
    num_records = x_tensor.get_shape().as_list()[0]
    std = 0.1
    fc_w = tf.Variable(tf.truncated_normal(shape=(x_dim,num_outputs),stddev=std,dtype=tf.float32))
    fc_b = tf.Variable(tf.zeros(num_outputs))
    fc = tf.nn.bias_add(tf.matmul(x_tensor,fc_w),fc_b)
    activate = tf.nn.relu(fc)
    return activate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### 输出层
#
# 实现 `output` 函数，向 x_tensor 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。
#
# **注意**：该层级不应应用 Activation、softmax 或交叉熵（cross entropy）。

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_dim = x_tensor.get_shape().as_list()[1]
    num_records = x_tensor.get_shape().as_list()[0]
    std = 0.1
    fc_w = tf.Variable(tf.truncated_normal((x_dim,num_outputs),stddev=std,dtype=tf.float32))
    fc_b = tf.Variable(tf.zeros(num_outputs))
    fc = tf.nn.bias_add(tf.matmul(x_tensor,fc_w),fc_b)
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### 创建卷积模型
#
# 实现函数 `conv_net`， 创建卷积神经网络模型。该函数传入一批图片 `x`，并输出对数（logits）。使用你在上方创建的层创建此模型：
#
# * 应用 1、2 或 3 个卷积和最大池化层（Convolution and Max Pool layers）
# * 应用一个扁平层（Flatten Layer）
# * 应用 1、2 或 3 个完全连接层（Fully Connected Layers）
# * 应用一个输出层（Output Layer）
# * 返回输出
# * 使用 `keep_prob` 向模型中的一个或多个层应用 [TensorFlow 的 Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv2d_1 = conv2d_maxpool(x,180,(11,11),(2,2),(4,4),(2,2))
    conv2d_2 = conv2d_maxpool(conv2d_1,128,(5,5),(2,2),(3,3),(2,2))
    conv2d_3 = conv2d_maxpool(conv2d_2,64,(3,3),(2,2),(3,3),(2,2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat = flatten(conv2d_3)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc_1 = fully_conn(flat,120)
    fc_2 = fully_conn(flat,100)
    fc_3 = fully_conn(flat,50)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(fc_2,10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# conv2d_shape:  (11, 11, 3, 180)
# conv2d_strides:  (1, 2, 2, 1)
# maxpool_ksize:  (1, 4, 4, 1)
# maxpool_strides:  (1, 2, 2, 1)
# conv2d_shape:  (5, 5, 180, 128)
# conv2d_strides:  (1, 2, 2, 1)
# maxpool_ksize:  (1, 3, 3, 1)
# maxpool_strides:  (1, 2, 2, 1)
# conv2d_shape:  (3, 3, 128, 64)
# conv2d_strides:  (1, 2, 2, 1)
# maxpool_ksize:  (1, 3, 3, 1)
# maxpool_strides:  (1, 2, 2, 1)
# (-1, 64)
# conv2d_shape:  (11, 11, 3, 180)
# conv2d_strides:  (1, 2, 2, 1)
# maxpool_ksize:  (1, 4, 4, 1)
# maxpool_strides:  (1, 2, 2, 1)
# conv2d_shape:  (5, 5, 180, 128)
# conv2d_strides:  (1, 2, 2, 1)
# maxpool_ksize:  (1, 3, 3, 1)
# maxpool_strides:  (1, 2, 2, 1)
# conv2d_shape:  (3, 3, 128, 64)
# conv2d_strides:  (1, 2, 2, 1)
# maxpool_ksize:  (1, 3, 3, 1)
# maxpool_strides:  (1, 2, 2, 1)
# (-1, 64)
# Neural Network Built!

# %% [markdown]
# ## 训练神经网络
#
# ### 单次优化
#
# 实现函数 `train_neural_network` 以进行单次优化（single optimization）。该优化应该使用 `optimizer` 优化 `session`，其中 `feed_dict` 具有以下参数：
#
# * `x` 表示图片输入
# * `y` 表示标签
# * `keep_prob` 表示丢弃的保留率
#
# 每个部分都会调用该函数，所以 `tf.global_variables_initializer()` 已经被调用。
#
# 注意：不需要返回任何内容。该函数只是用来优化神经网络。

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer,feed_dict={
        x:feature_batch,
        y:label_batch,
        keep_prob:keep_probability
        
    })
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### 显示数据
#
# 实现函数 `print_stats` 以输出损失和验证准确率。使用全局变量 `valid_features` 和 `valid_labels` 计算验证准确率。使用保留率 `1.0` 计算损失和验证准确率（loss and validation accuracy）。

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    cost = session.run(cost,feed_dict={
        x:feature_batch,
        y:label_batch,
        keep_prob:1.0
    })
    global valid_features
    global valid_labels
    accuracy = session.run(accuracy,feed_dict={
        x:valid_features,
        y:valid_labels
    })
    
    print("cost is: ",cost)
    print("accuracy is: ",accuracy)

# %% [markdown]
# ### 超参数
#
# 调试以下超参数：
# * 设置 `epochs` 表示神经网络停止学习或开始过拟合的迭代次数
# * 设置 `batch_size`，表示机器内存允许的部分最大体积。大部分人设为以下常见内存大小：
#
#  * 64
#  * 128
#  * 256
#  * ...
# * 设置 `keep_probability` 表示使用丢弃时保留节点的概率

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = 0.8

# %% [markdown]
# ### 在单个 CIFAR-10 部分上训练
#
# 我们先用单个部分，而不是用所有的 CIFAR-10 批次训练神经网络。这样可以节省时间，并对模型进行迭代，以提高准确率。最终验证准确率达到 50% 或以上之后，在下一部分对所有数据运行模型。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  cost is:  2.07376
# accuracy is:  0.283
# Epoch  2, CIFAR-10 Batch 1:  cost is:  1.87182
# accuracy is:  0.3772
# Epoch  3, CIFAR-10 Batch 1:  cost is:  1.62329
# accuracy is:  0.418
# Epoch  4, CIFAR-10 Batch 1:  cost is:  1.42143
# accuracy is:  0.4364
# Epoch  5, CIFAR-10 Batch 1:  cost is:  1.27377
# accuracy is:  0.4434
# Epoch  6, CIFAR-10 Batch 1:  cost is:  1.14948
# accuracy is:  0.4756
# Epoch  7, CIFAR-10 Batch 1:  cost is:  1.12661
# accuracy is:  0.4834
# Epoch  8, CIFAR-10 Batch 1:  cost is:  1.0012
# accuracy is:  0.5064
# Epoch  9, CIFAR-10 Batch 1:  cost is:  0.901042
# accuracy is:  0.5214
# Epoch 10, CIFAR-10 Batch 1:  cost is:  0.784106
# accuracy is:  0.531
# Epoch 11, CIFAR-10 Batch 1:  cost is:  0.783918
# accuracy is:  0.5322
# Epoch 12, CIFAR-10 Batch 1:  cost is:  0.653054
# accuracy is:  0.5138
# Epoch 13, CIFAR-10 Batch 1:  cost is:  0.581077
# accuracy is:  0.5006
# Epoch 14, CIFAR-10 Batch 1:  cost is:  0.513075
# accuracy is:  0.4926
# Epoch 15, CIFAR-10 Batch 1:  cost is:  0.447214
# accuracy is:  0.4784
# Epoch 16, CIFAR-10 Batch 1:  cost is:  0.386551
# accuracy is:  0.5242
# Epoch 17, CIFAR-10 Batch 1:  cost is:  0.293983
# accuracy is:  0.5346
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-124-0ebd1bbc35ad> in <module>()
#      11         batch_i = 1
#      12         for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
# ---> 13             train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
#      14         print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
#      15         print_stats(sess, batch_features, batch_labels, cost, accuracy)
#
# <ipython-input-121-bea159f11893> in train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch)
#      12         x:feature_batch,
#      13         y:label_batch,
# ---> 14         keep_prob:keep_probability
#      15
#      16     })
#
# ~/anaconda2/envs/dlnd35/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda2/envs/dlnd35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# ~/anaconda2/envs/dlnd35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~/anaconda2/envs/dlnd35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# ~/anaconda2/envs/dlnd35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### 完全训练模型
#
# 现在，单个 CIFAR-10 部分的准确率已经不错了，试试所有五个部分吧。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  cost is:  2.08883
# accuracy is:  0.282
# Epoch  1, CIFAR-10 Batch 2:  cost is:  1.70086
# accuracy is:  0.3792
# Epoch  1, CIFAR-10 Batch 3:  cost is:  1.50235
# accuracy is:  0.4122
# Epoch  1, CIFAR-10 Batch 4:  cost is:  1.41028
# accuracy is:  0.4684
# Epoch  1, CIFAR-10 Batch 5:  cost is:  1.32995
# accuracy is:  0.4778
# Epoch  2, CIFAR-10 Batch 1:  cost is:  1.42116
# accuracy is:  0.4784
# Epoch  2, CIFAR-10 Batch 2:  cost is:  1.27936
# accuracy is:  0.4968
# Epoch  2, CIFAR-10 Batch 3:  cost is:  1.05376
# accuracy is:  0.4954
# Epoch  2, CIFAR-10 Batch 4:  cost is:  1.08634
# accuracy is:  0.5392
# Epoch  2, CIFAR-10 Batch 5:  cost is:  1.18931
# accuracy is:  0.5184
# Epoch  3, CIFAR-10 Batch 1:  cost is:  1.1858
# accuracy is:  0.5394
# Epoch  3, CIFAR-10 Batch 2:  cost is:  1.10205
# accuracy is:  0.5148
# Epoch  3, CIFAR-10 Batch 3:  cost is:  0.813987
# accuracy is:  0.528
# Epoch  3, CIFAR-10 Batch 4:  cost is:  0.868314
# accuracy is:  0.5566
# Epoch  3, CIFAR-10 Batch 5:  cost is:  0.898459
# accuracy is:  0.5724
# Epoch  4, CIFAR-10 Batch 1:  cost is:  1.03005
# accuracy is:  0.567
# Epoch  4, CIFAR-10 Batch 2:  cost is:  0.874267
# accuracy is:  0.5722
# Epoch  4, CIFAR-10 Batch 3:  cost is:  0.651449
# accuracy is:  0.5536
# Epoch  4, CIFAR-10 Batch 4:  cost is:  0.767311
# accuracy is:  0.5718
# Epoch  4, CIFAR-10 Batch 5:  cost is:  0.762143
# accuracy is:  0.6082
# Epoch  5, CIFAR-10 Batch 1:  cost is:  0.892672
# accuracy is:  0.5862
# Epoch  5, CIFAR-10 Batch 2:  cost is:  0.820711
# accuracy is:  0.5708
# Epoch  5, CIFAR-10 Batch 3:  cost is:  0.582534
# accuracy is:  0.6092
# Epoch  5, CIFAR-10 Batch 4:  cost is:  0.6303
# accuracy is:  0.617
# Epoch  5, CIFAR-10 Batch 5:  cost is:  0.649643
# accuracy is:  0.6156
# Epoch  6, CIFAR-10 Batch 1:  cost is:  0.823223
# accuracy is:  0.5848
# Epoch  6, CIFAR-10 Batch 2:  cost is:  0.628251
# accuracy is:  0.5972
# Epoch  6, CIFAR-10 Batch 3:  cost is:  0.545517
# accuracy is:  0.6174
# Epoch  6, CIFAR-10 Batch 4:  cost is:  0.522283
# accuracy is:  0.6198
# Epoch  6, CIFAR-10 Batch 5:  cost is:  0.570832
# accuracy is:  0.6132
# Epoch  7, CIFAR-10 Batch 1:  cost is:  0.865604
# accuracy is:  0.593
# Epoch  7, CIFAR-10 Batch 2:  cost is:  0.607348
# accuracy is:  0.6084
# Epoch  7, CIFAR-10 Batch 3:  cost is:  0.453905
# accuracy is:  0.6158
# Epoch  7, CIFAR-10 Batch 4:  cost is:  0.445008
# accuracy is:  0.636
# Epoch  7, CIFAR-10 Batch 5:  cost is:  0.484634
# accuracy is:  0.6186
# Epoch  8, CIFAR-10 Batch 1:  cost is:  0.728253
# accuracy is:  0.6254
# Epoch  8, CIFAR-10 Batch 2:  cost is:  0.536052
# accuracy is:  0.622
# Epoch  8, CIFAR-10 Batch 3:  cost is:  0.365839
# accuracy is:  0.6306
# Epoch  8, CIFAR-10 Batch 4:  cost is:  0.386042
# accuracy is:  0.6256
# Epoch  8, CIFAR-10 Batch 5:  cost is:  0.378083
# accuracy is:  0.624
# Epoch  9, CIFAR-10 Batch 1:  cost is:  0.636194
# accuracy is:  0.6286
# Epoch  9, CIFAR-10 Batch 2:  cost is:  0.474916
# accuracy is:  0.6272
# Epoch  9, CIFAR-10 Batch 3:  cost is:  0.26504
# accuracy is:  0.6264
# Epoch  9, CIFAR-10 Batch 4:  cost is:  0.305534
# accuracy is:  0.6138
# Epoch  9, CIFAR-10 Batch 5:  cost is:  0.382153
# accuracy is:  0.6254
# Epoch 10, CIFAR-10 Batch 1:  cost is:  0.519956
# accuracy is:  0.637
# Epoch 10, CIFAR-10 Batch 2:  cost is:  0.340521
# accuracy is:  0.626
# Epoch 10, CIFAR-10 Batch 3:  cost is:  0.271361
# accuracy is:  0.6338
# Epoch 10, CIFAR-10 Batch 4:  cost is:  0.267786
# accuracy is:  0.622
# Epoch 10, CIFAR-10 Batch 5:  cost is:  0.333358
# accuracy is:  0.626
# Epoch 11, CIFAR-10 Batch 1:  cost is:  0.525095
# accuracy is:  0.643
# Epoch 11, CIFAR-10 Batch 2:  cost is:  0.371966
# accuracy is:  0.612
# Epoch 11, CIFAR-10 Batch 3:  cost is:  0.21428
# accuracy is:  0.6242
# Epoch 11, CIFAR-10 Batch 4:  cost is:  0.233168
# accuracy is:  0.6212
# Epoch 11, CIFAR-10 Batch 5:  cost is:  0.275722
# accuracy is:  0.6184
# Epoch 12, CIFAR-10 Batch 1:  cost is:  0.391357
# accuracy is:  0.636
# Epoch 12, CIFAR-10 Batch 2:  cost is:  0.363961
# accuracy is:  0.5936
# Epoch 12, CIFAR-10 Batch 3:  cost is:  0.25744
# accuracy is:  0.615
# Epoch 12, CIFAR-10 Batch 4:  cost is:  0.199103
# accuracy is:  0.6262
# Epoch 12, CIFAR-10 Batch 5:  cost is:  0.251017
# accuracy is:  0.6152
# Epoch 13, CIFAR-10 Batch 1:  cost is:  0.367098
# accuracy is:  0.6368
# Epoch 13, CIFAR-10 Batch 2:  cost is:  0.265906
# accuracy is:  0.61
# Epoch 13, CIFAR-10 Batch 3:  cost is:  0.163083
# accuracy is:  0.63
# Epoch 13, CIFAR-10 Batch 4:  cost is:  0.172018
# accuracy is:  0.6402
# Epoch 13, CIFAR-10 Batch 5:  cost is:  0.223641
# accuracy is:  0.6294
# Epoch 14, CIFAR-10 Batch 1:  cost is:  0.364353
# accuracy is:  0.6414
# Epoch 14, CIFAR-10 Batch 2:  cost is:  0.258208
# accuracy is:  0.6076
# Epoch 14, CIFAR-10 Batch 3:  cost is:  0.125803
# accuracy is:  0.6444
# Epoch 14, CIFAR-10 Batch 4:  cost is:  0.217379
# accuracy is:  0.6384
# Epoch 14, CIFAR-10 Batch 5:  cost is:  0.194867
# accuracy is:  0.6148
# Epoch 15, CIFAR-10 Batch 1:  cost is:  0.394027
# accuracy is:  0.6466
# Epoch 15, CIFAR-10 Batch 2:  cost is:  0.243738
# accuracy is:  0.606
# Epoch 15, CIFAR-10 Batch 3:  cost is:  0.149452
# accuracy is:  0.641
# Epoch 15, CIFAR-10 Batch 4:  cost is:  0.151997
# accuracy is:  0.6144
# Epoch 15, CIFAR-10 Batch 5:  cost is:  0.197201
# accuracy is:  0.5884
# Epoch 16, CIFAR-10 Batch 1:  cost is:  0.379567
# accuracy is:  0.6322
# Epoch 16, CIFAR-10 Batch 2:  cost is:  0.195116
# accuracy is:  0.5996
# Epoch 16, CIFAR-10 Batch 3:  cost is:  0.134292
# accuracy is:  0.6368
# Epoch 16, CIFAR-10 Batch 4:  cost is:  0.145021
# accuracy is:  0.603
# Epoch 16, CIFAR-10 Batch 5:  cost is:  0.166623
# accuracy is:  0.5972
# Epoch 17, CIFAR-10 Batch 1:  cost is:  0.287892
# accuracy is:  0.6174
# Epoch 17, CIFAR-10 Batch 2:  cost is:  0.144427
# accuracy is:  0.6206
# Epoch 17, CIFAR-10 Batch 3:  cost is:  0.10582
# accuracy is:  0.6252
# Epoch 17, CIFAR-10 Batch 4:  cost is:  0.165509
# accuracy is:  0.5962
# Epoch 17, CIFAR-10 Batch 5:  cost is:  0.168334
# accuracy is:  0.5978
# Epoch 18, CIFAR-10 Batch 1:  cost is:  0.21231
# accuracy is:  0.6286
# Epoch 18, CIFAR-10 Batch 2:  cost is:  0.143216
# accuracy is:  0.6086
# Epoch 18, CIFAR-10 Batch 3:  cost is:  0.10893
# accuracy is:  0.6238
# Epoch 18, CIFAR-10 Batch 4:  cost is:  0.129712
# accuracy is:  0.5722
# Epoch 18, CIFAR-10 Batch 5:  cost is:  0.178948
# accuracy is:  0.6022
# Epoch 19, CIFAR-10 Batch 1:  cost is:  0.200533
# accuracy is:  0.6284
# Epoch 19, CIFAR-10 Batch 2:  cost is:  0.144192
# accuracy is:  0.6176
# Epoch 19, CIFAR-10 Batch 3:  cost is:  0.0864164
# accuracy is:  0.6174
# Epoch 19, CIFAR-10 Batch 4:  cost is:  0.11426
# accuracy is:  0.6032
# Epoch 19, CIFAR-10 Batch 5:  cost is:  0.113197
# accuracy is:  0.6226
# Epoch 20, CIFAR-10 Batch 1:  cost is:  0.238182
# accuracy is:  0.6366
# Epoch 20, CIFAR-10 Batch 2:  cost is:  0.145974
# accuracy is:  0.6196
# Epoch 20, CIFAR-10 Batch 3:  cost is:  0.0721012
# accuracy is:  0.6214
# Epoch 20, CIFAR-10 Batch 4:  cost is:  0.0666588
# accuracy is:  0.6314
# Epoch 20, CIFAR-10 Batch 5:  cost is:  0.147297
# accuracy is:  0.5974
# Epoch 21, CIFAR-10 Batch 1:  cost is:  0.1827
# accuracy is:  0.6244
# Epoch 21, CIFAR-10 Batch 2:  cost is:  0.121999
# accuracy is:  0.6152
# Epoch 21, CIFAR-10 Batch 3:  cost is:  0.0956848
# accuracy is:  0.611
# Epoch 21, CIFAR-10 Batch 4:  cost is:  0.0944278
# accuracy is:  0.5966
# Epoch 21, CIFAR-10 Batch 5:  cost is:  0.099868
# accuracy is:  0.626
# Epoch 22, CIFAR-10 Batch 1:  cost is:  0.182014
# accuracy is:  0.6364
# Epoch 22, CIFAR-10 Batch 2:  cost is:  0.101905
# accuracy is:  0.609
# Epoch 22, CIFAR-10 Batch 3:  cost is:  0.0743088
# accuracy is:  0.6292
# Epoch 22, CIFAR-10 Batch 4:  cost is:  0.0898263
# accuracy is:  0.5948
# Epoch 22, CIFAR-10 Batch 5:  cost is:  0.0745167
# accuracy is:  0.6172
# Epoch 23, CIFAR-10 Batch 1:  cost is:  0.105325
# accuracy is:  0.6202
# Epoch 23, CIFAR-10 Batch 2:  cost is:  0.06742
# accuracy is:  0.6292
# Epoch 23, CIFAR-10 Batch 3:  cost is:  0.0752337
# accuracy is:  0.6
# Epoch 23, CIFAR-10 Batch 4:  cost is:  0.0718548
# accuracy is:  0.6118
# Epoch 23, CIFAR-10 Batch 5:  cost is:  0.0753939
# accuracy is:  0.6174
# Epoch 24, CIFAR-10 Batch 1:  cost is:  0.111673
# accuracy is:  0.618
# Epoch 24, CIFAR-10 Batch 2:  cost is:  0.0483046
# accuracy is:  0.6268
# Epoch 24, CIFAR-10 Batch 3:  cost is:  0.0502038
# accuracy is:  0.601
# Epoch 24, CIFAR-10 Batch 4:  cost is:  0.0537727
# accuracy is:  0.6288
# Epoch 24, CIFAR-10 Batch 5:  cost is:  0.0904707
# accuracy is:  0.61
# Epoch 25, CIFAR-10 Batch 1:  cost is:  0.165559
# accuracy is:  0.6228
# Epoch 25, CIFAR-10 Batch 2:  cost is:  0.0727072
# accuracy is:  0.6084
# Epoch 25, CIFAR-10 Batch 3:  cost is:  0.0699168
# accuracy is:  0.6194
# Epoch 25, CIFAR-10 Batch 4:  cost is:  0.0504245
# accuracy is:  0.6154
# Epoch 25, CIFAR-10 Batch 5:  cost is:  0.110877
# accuracy is:  0.6102
# Epoch 26, CIFAR-10 Batch 1:  cost is:  0.107995
# accuracy is:  0.6298
# Epoch 26, CIFAR-10 Batch 2:  cost is:  0.0348793
# accuracy is:  0.6
# Epoch 26, CIFAR-10 Batch 3:  cost is:  0.0612165
# accuracy is:  0.6078
# Epoch 26, CIFAR-10 Batch 4:  cost is:  0.0673621
# accuracy is:  0.609
# Epoch 26, CIFAR-10 Batch 5:  cost is:  0.0423188
# accuracy is:  0.614
# Epoch 27, CIFAR-10 Batch 1:  cost is:  0.0859539
# accuracy is:  0.6304
# Epoch 27, CIFAR-10 Batch 2:  cost is:  0.0360748
# accuracy is:  0.6156
# Epoch 27, CIFAR-10 Batch 3:  cost is:  0.0459839
# accuracy is:  0.6
# Epoch 27, CIFAR-10 Batch 4:  cost is:  0.0390996
# accuracy is:  0.6014
# Epoch 27, CIFAR-10 Batch 5:  cost is:  0.0344119
# accuracy is:  0.6406
# Epoch 28, CIFAR-10 Batch 1:  cost is:  0.0639005
# accuracy is:  0.6494
# Epoch 28, CIFAR-10 Batch 2:  cost is:  0.0180149
# accuracy is:  0.61
# Epoch 28, CIFAR-10 Batch 3:  cost is:  0.0724325
# accuracy is:  0.604
# Epoch 28, CIFAR-10 Batch 4:  cost is:  0.0518511
# accuracy is:  0.6248
# Epoch 28, CIFAR-10 Batch 5:  cost is:  0.029476
# accuracy is:  0.6278
# Epoch 29, CIFAR-10 Batch 1:  cost is:  0.0604292
# accuracy is:  0.636
# Epoch 29, CIFAR-10 Batch 2:  cost is:  0.0425786
# accuracy is:  0.6216
# Epoch 29, CIFAR-10 Batch 3:  cost is:  0.0657832
# accuracy is:  0.6086
# Epoch 29, CIFAR-10 Batch 4:  cost is:  0.0328406
# accuracy is:  0.6194
# Epoch 29, CIFAR-10 Batch 5:  cost is:  0.0382184
# accuracy is:  0.615
# Epoch 30, CIFAR-10 Batch 1:  cost is:  0.0853592
# accuracy is:  0.6182
# Epoch 30, CIFAR-10 Batch 2:  cost is:  0.0333257
# accuracy is:  0.617
# Epoch 30, CIFAR-10 Batch 3:  cost is:  0.0357437
# accuracy is:  0.6088
# Epoch 30, CIFAR-10 Batch 4:  cost is:  0.0655695
# accuracy is:  0.607
# Epoch 30, CIFAR-10 Batch 5:  cost is:  0.0425916
# accuracy is:  0.6184
# Epoch 31, CIFAR-10 Batch 1:  cost is:  0.107456
# accuracy is:  0.6158
# Epoch 31, CIFAR-10 Batch 2:  cost is:  0.0192192
# accuracy is:  0.6178
# Epoch 31, CIFAR-10 Batch 3:  cost is:  0.0246691
# accuracy is:  0.6098
# Epoch 31, CIFAR-10 Batch 4:  cost is:  0.0360046
# accuracy is:  0.6336
# Epoch 31, CIFAR-10 Batch 5:  cost is:  0.0206751
# accuracy is:  0.6226
# Epoch 32, CIFAR-10 Batch 1:  cost is:  0.0426866
# accuracy is:  0.631
# Epoch 32, CIFAR-10 Batch 2:  cost is:  0.0375719
# accuracy is:  0.6292
# Epoch 32, CIFAR-10 Batch 3:  cost is:  0.048354
# accuracy is:  0.5972
# Epoch 32, CIFAR-10 Batch 4:  cost is:  0.0244933
# accuracy is:  0.6228
# Epoch 32, CIFAR-10 Batch 5:  cost is:  0.0362148
# accuracy is:  0.6148
# Epoch 33, CIFAR-10 Batch 1:  cost is:  0.0235345
# accuracy is:  0.6198
# Epoch 33, CIFAR-10 Batch 2:  cost is:  0.0135278
# accuracy is:  0.6174
# Epoch 33, CIFAR-10 Batch 3:  cost is:  0.0325466
# accuracy is:  0.5892
# Epoch 33, CIFAR-10 Batch 4:  cost is:  0.0470302
# accuracy is:  0.6268
# Epoch 33, CIFAR-10 Batch 5:  cost is:  0.0140771
# accuracy is:  0.6308
# Epoch 34, CIFAR-10 Batch 1:  cost is:  0.0350084
# accuracy is:  0.6306
# Epoch 34, CIFAR-10 Batch 2:  cost is:  0.0307873
# accuracy is:  0.6074
# Epoch 34, CIFAR-10 Batch 3:  cost is:  0.0219999
# accuracy is:  0.6026
# Epoch 34, CIFAR-10 Batch 4:  cost is:  0.0208645
# accuracy is:  0.6196
# Epoch 34, CIFAR-10 Batch 5:  cost is:  0.0154755
# accuracy is:  0.6292
# Epoch 35, CIFAR-10 Batch 1:  cost is:  0.0339209
# accuracy is:  0.634
# Epoch 35, CIFAR-10 Batch 2:  cost is:  0.0175345
# accuracy is:  0.6112
# Epoch 35, CIFAR-10 Batch 3:  cost is:  0.0137596
# accuracy is:  0.6182
# Epoch 35, CIFAR-10 Batch 4:  cost is:  0.0334459
# accuracy is:  0.6078
# Epoch 35, CIFAR-10 Batch 5:  cost is:  0.0401658
# accuracy is:  0.6114
# Epoch 36, CIFAR-10 Batch 1:  cost is:  0.0302754
# accuracy is:  0.6162
# Epoch 36, CIFAR-10 Batch 2:  cost is:  0.0432503
# accuracy is:  0.6098
# Epoch 36, CIFAR-10 Batch 3:  cost is:  0.0223318
# accuracy is:  0.6144
# Epoch 36, CIFAR-10 Batch 4:  cost is:  0.0444599
# accuracy is:  0.6134
# Epoch 36, CIFAR-10 Batch 5:  cost is:  0.0175407
# accuracy is:  0.6238
# Epoch 37, CIFAR-10 Batch 1:  cost is:  0.0317223
# accuracy is:  0.627
# Epoch 37, CIFAR-10 Batch 2:  cost is:  0.0154477
# accuracy is:  0.6174
# Epoch 37, CIFAR-10 Batch 3:  cost is:  0.0248846
# accuracy is:  0.619
# Epoch 37, CIFAR-10 Batch 4:  cost is:  0.0199526
# accuracy is:  0.6166
# Epoch 37, CIFAR-10 Batch 5:  cost is:  0.0132466
# accuracy is:  0.631
# Epoch 38, CIFAR-10 Batch 1:  cost is:  0.0480479
# accuracy is:  0.623
# Epoch 38, CIFAR-10 Batch 2:  cost is:  0.0143726
# accuracy is:  0.62
# Epoch 38, CIFAR-10 Batch 3:  cost is:  0.0234425
# accuracy is:  0.6206
# Epoch 38, CIFAR-10 Batch 4:  cost is:  0.0424959
# accuracy is:  0.6166
# Epoch 38, CIFAR-10 Batch 5:  cost is:  0.0177917
# accuracy is:  0.6304
# Epoch 39, CIFAR-10 Batch 1:  cost is:  0.034714
# accuracy is:  0.6112
# Epoch 39, CIFAR-10 Batch 2:  cost is:  0.0182002
# accuracy is:  0.6284
# Epoch 39, CIFAR-10 Batch 3:  cost is:  0.0218569
# accuracy is:  0.6038
# Epoch 39, CIFAR-10 Batch 4:  cost is:  0.0380072
# accuracy is:  0.6292
# Epoch 39, CIFAR-10 Batch 5:  cost is:  0.0239224
# accuracy is:  0.6386
# Epoch 40, CIFAR-10 Batch 1:  cost is:  0.0322223
# accuracy is:  0.608
# Epoch 40, CIFAR-10 Batch 2:  cost is:  0.0132123
# accuracy is:  0.613
# Epoch 40, CIFAR-10 Batch 3:  cost is:  0.0047706
# accuracy is:  0.625
# Epoch 40, CIFAR-10 Batch 4:  cost is:  0.0106475
# accuracy is:  0.628
# Epoch 40, CIFAR-10 Batch 5:  cost is:  0.0147031
# accuracy is:  0.6264
# Epoch 41, CIFAR-10 Batch 1:  cost is:  0.0302874
# accuracy is:  0.6184
# Epoch 41, CIFAR-10 Batch 2:  cost is:  0.0116972
# accuracy is:  0.6062
# Epoch 41, CIFAR-10 Batch 3:  cost is:  0.00956529
# accuracy is:  0.5806
# Epoch 41, CIFAR-10 Batch 4:  cost is:  0.00857968
# accuracy is:  0.6198
# Epoch 41, CIFAR-10 Batch 5:  cost is:  0.0138271
# accuracy is:  0.6288
# Epoch 42, CIFAR-10 Batch 1:  cost is:  0.0315396
# accuracy is:  0.6008
# Epoch 42, CIFAR-10 Batch 2:  cost is:  0.0144888
# accuracy is:  0.5998
# Epoch 42, CIFAR-10 Batch 3:  cost is:  0.0113083
# accuracy is:  0.6084
# Epoch 42, CIFAR-10 Batch 4:  cost is:  0.0243192
# accuracy is:  0.6258
# Epoch 42, CIFAR-10 Batch 5:  cost is:  0.0173246
# accuracy is:  0.6212
# Epoch 43, CIFAR-10 Batch 1:  cost is:  0.0185767
# accuracy is:  0.6324
# Epoch 43, CIFAR-10 Batch 2:  cost is:  0.00882018
# accuracy is:  0.6284
# Epoch 43, CIFAR-10 Batch 3:  cost is:  0.0101563
# accuracy is:  0.6162
# Epoch 43, CIFAR-10 Batch 4:  cost is:  0.00508842
# accuracy is:  0.6178
# Epoch 43, CIFAR-10 Batch 5:  cost is:  0.0504296
# accuracy is:  0.6124
# Epoch 44, CIFAR-10 Batch 1:  cost is:  0.0116213
# accuracy is:  0.6272
# Epoch 44, CIFAR-10 Batch 2:  cost is:  0.00669471
# accuracy is:  0.6256
# Epoch 44, CIFAR-10 Batch 3:  cost is:  0.00841796
# accuracy is:  0.6066
# Epoch 44, CIFAR-10 Batch 4:  cost is:  0.0255618
# accuracy is:  0.6066
# Epoch 44, CIFAR-10 Batch 5:  cost is:  0.0128233
# accuracy is:  0.609
# Epoch 45, CIFAR-10 Batch 1:  cost is:  0.01364
# accuracy is:  0.62
# Epoch 45, CIFAR-10 Batch 2:  cost is:  0.00912363
# accuracy is:  0.6292
# Epoch 45, CIFAR-10 Batch 3:  cost is:  0.0210766
# accuracy is:  0.6126
# Epoch 45, CIFAR-10 Batch 4:  cost is:  0.0218401
# accuracy is:  0.6152
# Epoch 45, CIFAR-10 Batch 5:  cost is:  0.0169246
# accuracy is:  0.6186
# Epoch 46, CIFAR-10 Batch 1:  cost is:  0.00609751
# accuracy is:  0.6344
# Epoch 46, CIFAR-10 Batch 2:  cost is:  0.00919005
# accuracy is:  0.6302
# Epoch 46, CIFAR-10 Batch 3:  cost is:  0.0169265
# accuracy is:  0.6154
# Epoch 46, CIFAR-10 Batch 4:  cost is:  0.0116995
# accuracy is:  0.6164
# Epoch 46, CIFAR-10 Batch 5:  cost is:  0.0179611
# accuracy is:  0.6226
# Epoch 47, CIFAR-10 Batch 1:  cost is:  0.0187908
# accuracy is:  0.6278
# Epoch 47, CIFAR-10 Batch 2:  cost is:  0.0096152
# accuracy is:  0.618
# Epoch 47, CIFAR-10 Batch 3:  cost is:  0.00298018
# accuracy is:  0.6308
# Epoch 47, CIFAR-10 Batch 4:  cost is:  0.0177169
# accuracy is:  0.6152
# Epoch 47, CIFAR-10 Batch 5:  cost is:  0.0060919
# accuracy is:  0.6346
# Epoch 48, CIFAR-10 Batch 1:  cost is:  0.0144578
# accuracy is:  0.6218
# Epoch 48, CIFAR-10 Batch 2:  cost is:  0.00852877
# accuracy is:  0.606
# Epoch 48, CIFAR-10 Batch 3:  cost is:  0.00667778
# accuracy is:  0.6334
# Epoch 48, CIFAR-10 Batch 4:  cost is:  0.0112308
# accuracy is:  0.6282
# Epoch 48, CIFAR-10 Batch 5:  cost is:  0.0175029
# accuracy is:  0.6232
# Epoch 49, CIFAR-10 Batch 1:  cost is:  0.00800748
# accuracy is:  0.6272
# Epoch 49, CIFAR-10 Batch 2:  cost is:  0.00721434
# accuracy is:  0.6354
# Epoch 49, CIFAR-10 Batch 3:  cost is:  0.001306
# accuracy is:  0.6356
# Epoch 49, CIFAR-10 Batch 4:  cost is:  0.0106624
# accuracy is:  0.6178
# Epoch 49, CIFAR-10 Batch 5:  cost is:  0.0134156
# accuracy is:  0.6158
# Epoch 50, CIFAR-10 Batch 1:  cost is:  0.014241
# accuracy is:  0.633
# Epoch 50, CIFAR-10 Batch 2:  cost is:  0.00541799
# accuracy is:  0.6296
# Epoch 50, CIFAR-10 Batch 3:  cost is:  0.00383272
# accuracy is:  0.6392
# Epoch 50, CIFAR-10 Batch 4:  cost is:  0.00722624
# accuracy is:  0.6258
# Epoch 50, CIFAR-10 Batch 5:  cost is:  0.0291658
# accuracy is:  0.637
# Epoch 51, CIFAR-10 Batch 1:  cost is:  0.0117474
# accuracy is:  0.6218
# Epoch 51, CIFAR-10 Batch 2:  cost is:  0.00756753
# accuracy is:  0.621
# Epoch 51, CIFAR-10 Batch 3:  cost is:  0.00464853
# accuracy is:  0.6396
# Epoch 51, CIFAR-10 Batch 4:  cost is:  0.0328873
# accuracy is:  0.6272
# Epoch 51, CIFAR-10 Batch 5:  cost is:  0.00909022
# accuracy is:  0.6388
# Epoch 52, CIFAR-10 Batch 1:  cost is:  0.0180552
# accuracy is:  0.6172
# Epoch 52, CIFAR-10 Batch 2:  cost is:  0.00617385
# accuracy is:  0.6408
# Epoch 52, CIFAR-10 Batch 3:  cost is:  0.00555942
# accuracy is:  0.6274
# Epoch 52, CIFAR-10 Batch 4:  cost is:  0.0110114
# accuracy is:  0.6194
# Epoch 52, CIFAR-10 Batch 5:  cost is:  0.0128886
# accuracy is:  0.6304
# Epoch 53, CIFAR-10 Batch 1:  cost is:  0.0248998
# accuracy is:  0.6208
# Epoch 53, CIFAR-10 Batch 2:  cost is:  0.0160819
# accuracy is:  0.6312
# Epoch 53, CIFAR-10 Batch 3:  cost is:  0.00885742
# accuracy is:  0.6312
# Epoch 53, CIFAR-10 Batch 4:  cost is:  0.0150453
# accuracy is:  0.6426
# Epoch 53, CIFAR-10 Batch 5:  cost is:  0.0105752
# accuracy is:  0.6316
# Epoch 54, CIFAR-10 Batch 1:  cost is:  0.0185956
# accuracy is:  0.6224
# Epoch 54, CIFAR-10 Batch 2:  cost is:  0.00737026
# accuracy is:  0.6344
# Epoch 54, CIFAR-10 Batch 3:  cost is:  0.00432488
# accuracy is:  0.6316
# Epoch 54, CIFAR-10 Batch 4:  cost is:  0.0119464
# accuracy is:  0.6284
# Epoch 54, CIFAR-10 Batch 5:  cost is:  0.012888
# accuracy is:  0.6314
# Epoch 55, CIFAR-10 Batch 1:  cost is:  0.0184271
# accuracy is:  0.6136
# Epoch 55, CIFAR-10 Batch 2:  cost is:  0.00404501
# accuracy is:  0.644
# Epoch 55, CIFAR-10 Batch 3:  cost is:  0.00443687
# accuracy is:  0.6302
# Epoch 55, CIFAR-10 Batch 4:  cost is:  0.00978268
# accuracy is:  0.6302
# Epoch 55, CIFAR-10 Batch 5:  cost is:  0.00485107
# accuracy is:  0.6366
# Epoch 56, CIFAR-10 Batch 1:  cost is:  0.0240053
# accuracy is:  0.613
# Epoch 56, CIFAR-10 Batch 2:  cost is:  0.00655203
# accuracy is:  0.6418
# Epoch 56, CIFAR-10 Batch 3:  cost is:  0.0131228
# accuracy is:  0.627
# Epoch 56, CIFAR-10 Batch 4:  cost is:  0.0284234
# accuracy is:  0.625
# Epoch 56, CIFAR-10 Batch 5:  cost is:  0.00629566
# accuracy is:  0.6486
# Epoch 57, CIFAR-10 Batch 1:  cost is:  0.0299134
# accuracy is:  0.6112
# Epoch 57, CIFAR-10 Batch 2:  cost is:  0.0111493
# accuracy is:  0.6364
# Epoch 57, CIFAR-10 Batch 3:  cost is:  0.0184758
# accuracy is:  0.6378
# Epoch 57, CIFAR-10 Batch 4:  cost is:  0.00356241
# accuracy is:  0.6266
# Epoch 57, CIFAR-10 Batch 5:  cost is:  0.0120052
# accuracy is:  0.6314
# Epoch 58, CIFAR-10 Batch 1:  cost is:  0.0183504
# accuracy is:  0.6186
# Epoch 58, CIFAR-10 Batch 2:  cost is:  0.00543436
# accuracy is:  0.6322
# Epoch 58, CIFAR-10 Batch 3:  cost is:  0.00412427
# accuracy is:  0.6232
# Epoch 58, CIFAR-10 Batch 4:  cost is:  0.00452922
# accuracy is:  0.6164
# Epoch 58, CIFAR-10 Batch 5:  cost is:  0.00433498
# accuracy is:  0.6346
# Epoch 59, CIFAR-10 Batch 1:  cost is:  0.0107008
# accuracy is:  0.6298
# Epoch 59, CIFAR-10 Batch 2:  cost is:  0.00642613
# accuracy is:  0.6356
# Epoch 59, CIFAR-10 Batch 3:  cost is:  0.00479735
# accuracy is:  0.638
# Epoch 59, CIFAR-10 Batch 4:  cost is:  0.00933784
# accuracy is:  0.6128
# Epoch 59, CIFAR-10 Batch 5:  cost is:  0.00663546
# accuracy is:  0.6438
# Epoch 60, CIFAR-10 Batch 1:  cost is:  0.0078175
# accuracy is:  0.6186
# Epoch 60, CIFAR-10 Batch 2:  cost is:  0.00565638
# accuracy is:  0.6326
# Epoch 60, CIFAR-10 Batch 3:  cost is:  0.007773
# accuracy is:  0.633
# Epoch 60, CIFAR-10 Batch 4:  cost is:  0.00249205
# accuracy is:  0.6234
# Epoch 60, CIFAR-10 Batch 5:  cost is:  0.0112643
# accuracy is:  0.6406
# Epoch 61, CIFAR-10 Batch 1:  cost is:  0.00698294
# accuracy is:  0.6418
# Epoch 61, CIFAR-10 Batch 2:  cost is:  0.0201362
# accuracy is:  0.6386
# Epoch 61, CIFAR-10 Batch 3:  cost is:  0.00097066
# accuracy is:  0.6386
# Epoch 61, CIFAR-10 Batch 4:  cost is:  0.00999402
# accuracy is:  0.6206
# Epoch 61, CIFAR-10 Batch 5:  cost is:  0.00861912
# accuracy is:  0.6452
# Epoch 62, CIFAR-10 Batch 1:  cost is:  0.00887224
# accuracy is:  0.631
# Epoch 62, CIFAR-10 Batch 2:  cost is:  0.00853472
# accuracy is:  0.6252
# Epoch 62, CIFAR-10 Batch 3:  cost is:  0.00827202
# accuracy is:  0.6262
# Epoch 62, CIFAR-10 Batch 4:  cost is:  0.0133497
# accuracy is:  0.6286
# Epoch 62, CIFAR-10 Batch 5:  cost is:  0.00262454
# accuracy is:  0.6396
# Epoch 63, CIFAR-10 Batch 1:  cost is:  0.0101287
# accuracy is:  0.6472
# Epoch 63, CIFAR-10 Batch 2:  cost is:  0.0102369
# accuracy is:  0.6006
# Epoch 63, CIFAR-10 Batch 3:  cost is:  0.00972034
# accuracy is:  0.6308
# Epoch 63, CIFAR-10 Batch 4:  cost is:  0.00659519
# accuracy is:  0.6226
# Epoch 63, CIFAR-10 Batch 5:  cost is:  0.00893594
# accuracy is:  0.6508
# Epoch 64, CIFAR-10 Batch 1:  cost is:  0.00341788
# accuracy is:  0.6392
# Epoch 64, CIFAR-10 Batch 2:  cost is:  0.00966012
# accuracy is:  0.6104
# Epoch 64, CIFAR-10 Batch 3:  cost is:  0.0175302
# accuracy is:  0.6354
# Epoch 64, CIFAR-10 Batch 4:  cost is:  0.00453562
# accuracy is:  0.626
# Epoch 64, CIFAR-10 Batch 5:  cost is:  0.00205128
# accuracy is:  0.6466
# Epoch 65, CIFAR-10 Batch 1:  cost is:  0.00317282
# accuracy is:  0.6362
# Epoch 65, CIFAR-10 Batch 2:  cost is:  0.00168844
# accuracy is:  0.5894
# Epoch 65, CIFAR-10 Batch 3:  cost is:  0.00117299
# accuracy is:  0.631
# Epoch 65, CIFAR-10 Batch 4:  cost is:  0.0100405
# accuracy is:  0.6056
# Epoch 65, CIFAR-10 Batch 5:  cost is:  0.00471851
# accuracy is:  0.6292
# Epoch 66, CIFAR-10 Batch 1:  cost is:  0.00505804
# accuracy is:  0.6366
# Epoch 66, CIFAR-10 Batch 2:  cost is:  0.00427523
# accuracy is:  0.6052
# Epoch 66, CIFAR-10 Batch 3:  cost is:  0.000418815
# accuracy is:  0.636
# Epoch 66, CIFAR-10 Batch 4:  cost is:  0.0017128
# accuracy is:  0.6236
# Epoch 66, CIFAR-10 Batch 5:  cost is:  0.00268253
# accuracy is:  0.6388
# Epoch 67, CIFAR-10 Batch 1:  cost is:  0.016595
# accuracy is:  0.6394
# Epoch 67, CIFAR-10 Batch 2:  cost is:  0.00515246
# accuracy is:  0.5772
# Epoch 67, CIFAR-10 Batch 3:  cost is:  0.0026819
# accuracy is:  0.634
# Epoch 67, CIFAR-10 Batch 4:  cost is:  0.00469505
# accuracy is:  0.6276
# Epoch 67, CIFAR-10 Batch 5:  cost is:  0.00785622
# accuracy is:  0.6298
# Epoch 68, CIFAR-10 Batch 1:  cost is:  0.00319288
# accuracy is:  0.6338
# Epoch 68, CIFAR-10 Batch 2:  cost is:  0.00308364
# accuracy is:  0.6268
# Epoch 68, CIFAR-10 Batch 3:  cost is:  0.00379938
# accuracy is:  0.6472
# Epoch 68, CIFAR-10 Batch 4:  cost is:  0.00478475
# accuracy is:  0.6254
# Epoch 68, CIFAR-10 Batch 5:  cost is:  0.00712567
# accuracy is:  0.6418
# Epoch 69, CIFAR-10 Batch 1:  cost is:  0.00239858
# accuracy is:  0.6326
# Epoch 69, CIFAR-10 Batch 2:  cost is:  0.01284
# accuracy is:  0.6082
# Epoch 69, CIFAR-10 Batch 3:  cost is:  0.000959429
# accuracy is:  0.6406
# Epoch 69, CIFAR-10 Batch 4:  cost is:  0.00250167
# accuracy is:  0.6266
# Epoch 69, CIFAR-10 Batch 5:  cost is:  0.00414044
# accuracy is:  0.6332
# Epoch 70, CIFAR-10 Batch 1:  cost is:  0.00495045
# accuracy is:  0.6338
# Epoch 70, CIFAR-10 Batch 2:  cost is:  0.00606169
# accuracy is:  0.6216
# Epoch 70, CIFAR-10 Batch 3:  cost is:  0.00270399
# accuracy is:  0.639
# Epoch 70, CIFAR-10 Batch 4:  cost is:  0.00198449
# accuracy is:  0.6184
# Epoch 70, CIFAR-10 Batch 5:  cost is:  0.0132793
# accuracy is:  0.6316
# Epoch 71, CIFAR-10 Batch 1:  cost is:  0.00983182
# accuracy is:  0.631
# Epoch 71, CIFAR-10 Batch 2:  cost is:  0.0144647
# accuracy is:  0.6254
# Epoch 71, CIFAR-10 Batch 3:  cost is:  0.00243563
# accuracy is:  0.6472
# Epoch 71, CIFAR-10 Batch 4:  cost is:  0.00196431
# accuracy is:  0.6256
# Epoch 71, CIFAR-10 Batch 5:  cost is:  0.00322036
# accuracy is:  0.6416
# Epoch 72, CIFAR-10 Batch 1:  cost is:  0.00824113
# accuracy is:  0.6322
# Epoch 72, CIFAR-10 Batch 2:  cost is:  0.00364241
# accuracy is:  0.6234
# Epoch 72, CIFAR-10 Batch 3:  cost is:  0.00181076
# accuracy is:  0.6464
# Epoch 72, CIFAR-10 Batch 4:  cost is:  0.00231774
# accuracy is:  0.6238
# Epoch 72, CIFAR-10 Batch 5:  cost is:  0.00552106
# accuracy is:  0.6402
# Epoch 73, CIFAR-10 Batch 1:  cost is:  0.00317029
# accuracy is:  0.6444
# Epoch 73, CIFAR-10 Batch 2:  cost is:  0.0110718
# accuracy is:  0.6306
# Epoch 73, CIFAR-10 Batch 3:  cost is:  0.0061268
# accuracy is:  0.6348
# Epoch 73, CIFAR-10 Batch 4:  cost is:  0.00116232
# accuracy is:  0.6386
# Epoch 73, CIFAR-10 Batch 5:  cost is:  0.00670078
# accuracy is:  0.6376
# Epoch 74, CIFAR-10 Batch 1:  cost is:  0.00562863
# accuracy is:  0.6272
# Epoch 74, CIFAR-10 Batch 2:  cost is:  0.0019116
# accuracy is:  0.6412
# Epoch 74, CIFAR-10 Batch 3:  cost is:  0.00168831
# accuracy is:  0.627
# Epoch 74, CIFAR-10 Batch 4:  cost is:  0.00684509
# accuracy is:  0.6192
# Epoch 74, CIFAR-10 Batch 5:  cost is:  0.00934509
# accuracy is:  0.6358
# Epoch 75, CIFAR-10 Batch 1:  cost is:  0.00304426
# accuracy is:  0.6354
# Epoch 75, CIFAR-10 Batch 2:  cost is:  0.00117636
# accuracy is:  0.635
# Epoch 75, CIFAR-10 Batch 3:  cost is:  0.00180018
# accuracy is:  0.634
# Epoch 75, CIFAR-10 Batch 4:  cost is:  0.00356905
# accuracy is:  0.6236
# Epoch 75, CIFAR-10 Batch 5:  cost is:  0.00678544
# accuracy is:  0.6342
# Epoch 76, CIFAR-10 Batch 1:  cost is:  0.00278683
# accuracy is:  0.6344
# Epoch 76, CIFAR-10 Batch 2:  cost is:  0.00312412
# accuracy is:  0.6306
# Epoch 76, CIFAR-10 Batch 3:  cost is:  0.00298689
# accuracy is:  0.6318
# Epoch 76, CIFAR-10 Batch 4:  cost is:  0.00129376
# accuracy is:  0.6308
# Epoch 76, CIFAR-10 Batch 5:  cost is:  0.00238734
# accuracy is:  0.6386
# Epoch 77, CIFAR-10 Batch 1:  cost is:  0.00927362
# accuracy is:  0.6366
# Epoch 77, CIFAR-10 Batch 2:  cost is:  0.00517572
# accuracy is:  0.642
# Epoch 77, CIFAR-10 Batch 3:  cost is:  0.00565663
# accuracy is:  0.6276
# Epoch 77, CIFAR-10 Batch 4:  cost is:  0.00754297
# accuracy is:  0.6358
# Epoch 77, CIFAR-10 Batch 5:  cost is:  0.00209834
# accuracy is:  0.6486
# Epoch 78, CIFAR-10 Batch 1:  cost is:  0.00894752
# accuracy is:  0.6392
# Epoch 78, CIFAR-10 Batch 2:  cost is:  0.00579957
# accuracy is:  0.6358
# Epoch 78, CIFAR-10 Batch 3:  cost is:  0.00327319
# accuracy is:  0.6346
# Epoch 78, CIFAR-10 Batch 4:  cost is:  0.00262699
# accuracy is:  0.64
# Epoch 78, CIFAR-10 Batch 5:  cost is:  0.00728717
# accuracy is:  0.6322
# Epoch 79, CIFAR-10 Batch 1:  cost is:  0.00449932
# accuracy is:  0.6384
# Epoch 79, CIFAR-10 Batch 2:  cost is:  0.00325678
# accuracy is:  0.6334
# Epoch 79, CIFAR-10 Batch 3:  cost is:  0.0028936
# accuracy is:  0.6364
# Epoch 79, CIFAR-10 Batch 4:  cost is:  0.00085778
# accuracy is:  0.6416
# Epoch 79, CIFAR-10 Batch 5:  cost is:  0.00388343
# accuracy is:  0.6302
# Epoch 80, CIFAR-10 Batch 1:  cost is:  0.00859617
# accuracy is:  0.641
# Epoch 80, CIFAR-10 Batch 2:  cost is:  0.00707758
# accuracy is:  0.6202
# Epoch 80, CIFAR-10 Batch 3:  cost is:  0.00342115
# accuracy is:  0.6446
# Epoch 80, CIFAR-10 Batch 4:  cost is:  0.00163963
# accuracy is:  0.6388
# Epoch 80, CIFAR-10 Batch 5:  cost is:  0.0035393
# accuracy is:  0.6406
# Epoch 81, CIFAR-10 Batch 1:  cost is:  0.00646944
# accuracy is:  0.6434
# Epoch 81, CIFAR-10 Batch 2:  cost is:  0.00194838
# accuracy is:  0.6448
# Epoch 81, CIFAR-10 Batch 3:  cost is:  0.00703779
# accuracy is:  0.6382
# Epoch 81, CIFAR-10 Batch 4:  cost is:  0.000255642
# accuracy is:  0.6326
# Epoch 81, CIFAR-10 Batch 5:  cost is:  0.00328529
# accuracy is:  0.6446
# Epoch 82, CIFAR-10 Batch 1:  cost is:  0.00527399
# accuracy is:  0.6416
# Epoch 82, CIFAR-10 Batch 2:  cost is:  0.000634797
# accuracy is:  0.6426
# Epoch 82, CIFAR-10 Batch 3:  cost is:  0.00371558
# accuracy is:  0.6236
# Epoch 82, CIFAR-10 Batch 4:  cost is:  0.00177102
# accuracy is:  0.6468
# Epoch 82, CIFAR-10 Batch 5:  cost is:  0.0162128
# accuracy is:  0.6432
# Epoch 83, CIFAR-10 Batch 1:  cost is:  0.00957344
# accuracy is:  0.6468
# Epoch 83, CIFAR-10 Batch 2:  cost is:  0.000913761
# accuracy is:  0.642
# Epoch 83, CIFAR-10 Batch 3:  cost is:  0.00789271
# accuracy is:  0.6338
# Epoch 83, CIFAR-10 Batch 4:  cost is:  0.00970167
# accuracy is:  0.6324
# Epoch 83, CIFAR-10 Batch 5:  cost is:  0.004013
# accuracy is:  0.6414
# Epoch 84, CIFAR-10 Batch 1:  cost is:  0.00663978
# accuracy is:  0.637
# Epoch 84, CIFAR-10 Batch 2:  cost is:  0.000909085
# accuracy is:  0.6462
# Epoch 84, CIFAR-10 Batch 3:  cost is:  0.00142343
# accuracy is:  0.65
# Epoch 84, CIFAR-10 Batch 4:  cost is:  0.0001426
# accuracy is:  0.6418
# Epoch 84, CIFAR-10 Batch 5:  cost is:  0.00252344
# accuracy is:  0.6386
# Epoch 85, CIFAR-10 Batch 1:  cost is:  0.00514974
# accuracy is:  0.6344
# Epoch 85, CIFAR-10 Batch 2:  cost is:  0.00140886
# accuracy is:  0.6384
# Epoch 85, CIFAR-10 Batch 3:  cost is:  0.00266717
# accuracy is:  0.642
# Epoch 85, CIFAR-10 Batch 4:  cost is:  0.00178386
# accuracy is:  0.6432
# Epoch 85, CIFAR-10 Batch 5:  cost is:  0.0054573
# accuracy is:  0.6378
# Epoch 86, CIFAR-10 Batch 1:  cost is:  0.00269241
# accuracy is:  0.6396
# Epoch 86, CIFAR-10 Batch 2:  cost is:  0.000385921
# accuracy is:  0.6394
# Epoch 86, CIFAR-10 Batch 3:  cost is:  0.000786808
# accuracy is:  0.6414
# Epoch 86, CIFAR-10 Batch 4:  cost is:  0.00151245
# accuracy is:  0.6372
# Epoch 86, CIFAR-10 Batch 5:  cost is:  0.0475033
# accuracy is:  0.6416
# Epoch 87, CIFAR-10 Batch 1:  cost is:  0.00973273
# accuracy is:  0.6348
# Epoch 87, CIFAR-10 Batch 2:  cost is:  0.00226586
# accuracy is:  0.6222
# Epoch 87, CIFAR-10 Batch 3:  cost is:  0.000927576
# accuracy is:  0.646
# Epoch 87, CIFAR-10 Batch 4:  cost is:  0.00176577
# accuracy is:  0.6254
# Epoch 87, CIFAR-10 Batch 5:  cost is:  0.00148434
# accuracy is:  0.6548
# Epoch 88, CIFAR-10 Batch 1:  cost is:  0.00137973
# accuracy is:  0.6444
# Epoch 88, CIFAR-10 Batch 2:  cost is:  0.000918625
# accuracy is:  0.6344
# Epoch 88, CIFAR-10 Batch 3:  cost is:  0.00332924
# accuracy is:  0.6384
# Epoch 88, CIFAR-10 Batch 4:  cost is:  0.00195244
# accuracy is:  0.6342
# Epoch 88, CIFAR-10 Batch 5:  cost is:  0.000847836
# accuracy is:  0.642
# Epoch 89, CIFAR-10 Batch 1:  cost is:  0.00788989
# accuracy is:  0.645
# Epoch 89, CIFAR-10 Batch 2:  cost is:  0.00172746
# accuracy is:  0.6412
# Epoch 89, CIFAR-10 Batch 3:  cost is:  0.00152975
# accuracy is:  0.6464
# Epoch 89, CIFAR-10 Batch 4:  cost is:  0.00440904
# accuracy is:  0.6398
# Epoch 89, CIFAR-10 Batch 5:  cost is:  0.00404281
# accuracy is:  0.6394
# Epoch 90, CIFAR-10 Batch 1:  cost is:  0.00552106
# accuracy is:  0.6502
# Epoch 90, CIFAR-10 Batch 2:  cost is:  0.0031405
# accuracy is:  0.6402
# Epoch 90, CIFAR-10 Batch 3:  cost is:  0.0044569
# accuracy is:  0.6378
# Epoch 90, CIFAR-10 Batch 4:  cost is:  0.00422307
# accuracy is:  0.6324
# Epoch 90, CIFAR-10 Batch 5:  cost is:  0.00219071
# accuracy is:  0.6404
# Epoch 91, CIFAR-10 Batch 1:  cost is:  0.006082
# accuracy is:  0.6472
# Epoch 91, CIFAR-10 Batch 2:  cost is:  0.00248708
# accuracy is:  0.6372
# Epoch 91, CIFAR-10 Batch 3:  cost is:  0.000370702
# accuracy is:  0.6492
# Epoch 91, CIFAR-10 Batch 4:  cost is:  0.000944662
# accuracy is:  0.6322
# Epoch 91, CIFAR-10 Batch 5:  cost is:  0.00158265
# accuracy is:  0.64
# Epoch 92, CIFAR-10 Batch 1:  cost is:  0.00219453
# accuracy is:  0.6388
# Epoch 92, CIFAR-10 Batch 2:  cost is:  0.0041978
# accuracy is:  0.6362
# Epoch 92, CIFAR-10 Batch 3:  cost is:  0.00618432
# accuracy is:  0.6368
# Epoch 92, CIFAR-10 Batch 4:  cost is:  0.000851369
# accuracy is:  0.6278
# Epoch 92, CIFAR-10 Batch 5:  cost is:  0.00251916
# accuracy is:  0.6456
# Epoch 93, CIFAR-10 Batch 1:  cost is:  0.00681651
# accuracy is:  0.655
# Epoch 93, CIFAR-10 Batch 2:  cost is:  0.00203341
# accuracy is:  0.629
# Epoch 93, CIFAR-10 Batch 3:  cost is:  0.00162514
# accuracy is:  0.6362
# Epoch 93, CIFAR-10 Batch 4:  cost is:  0.00523259
# accuracy is:  0.6364
# Epoch 93, CIFAR-10 Batch 5:  cost is:  0.00274011
# accuracy is:  0.6458
# Epoch 94, CIFAR-10 Batch 1:  cost is:  0.0023265
# accuracy is:  0.6596
# Epoch 94, CIFAR-10 Batch 2:  cost is:  0.00404944
# accuracy is:  0.6348
# Epoch 94, CIFAR-10 Batch 3:  cost is:  0.00163343
# accuracy is:  0.6534
# Epoch 94, CIFAR-10 Batch 4:  cost is:  0.000990678
# accuracy is:  0.6448
# Epoch 94, CIFAR-10 Batch 5:  cost is:  0.00494277
# accuracy is:  0.6514
# Epoch 95, CIFAR-10 Batch 1:  cost is:  0.00158705
# accuracy is:  0.645
# Epoch 95, CIFAR-10 Batch 2:  cost is:  0.00221583
# accuracy is:  0.6448
# Epoch 95, CIFAR-10 Batch 3:  cost is:  0.00235646
# accuracy is:  0.662
# Epoch 95, CIFAR-10 Batch 4:  cost is:  0.00226373
# accuracy is:  0.64
# Epoch 95, CIFAR-10 Batch 5:  cost is:  0.000733664
# accuracy is:  0.6444
# Epoch 96, CIFAR-10 Batch 1:  cost is:  0.0100788
# accuracy is:  0.657
# Epoch 96, CIFAR-10 Batch 2:  cost is:  0.00349704
# accuracy is:  0.6492
# Epoch 96, CIFAR-10 Batch 3:  cost is:  0.00102437
# accuracy is:  0.637
# Epoch 96, CIFAR-10 Batch 4:  cost is:  0.000908442
# accuracy is:  0.6432
# Epoch 96, CIFAR-10 Batch 5:  cost is:  0.000938777
# accuracy is:  0.6376
# Epoch 97, CIFAR-10 Batch 1:  cost is:  0.00554435
# accuracy is:  0.6438
# Epoch 97, CIFAR-10 Batch 2:  cost is:  0.00100298
# accuracy is:  0.645
# Epoch 97, CIFAR-10 Batch 3:  cost is:  0.00287883
# accuracy is:  0.6404
# Epoch 97, CIFAR-10 Batch 4:  cost is:  0.00217877
# accuracy is:  0.6414
# Epoch 97, CIFAR-10 Batch 5:  cost is:  0.000728082
# accuracy is:  0.6476
# Epoch 98, CIFAR-10 Batch 1:  cost is:  0.00338523
# accuracy is:  0.6602
# Epoch 98, CIFAR-10 Batch 2:  cost is:  0.000929625
# accuracy is:  0.651
# Epoch 98, CIFAR-10 Batch 3:  cost is:  0.000897183
# accuracy is:  0.651
# Epoch 98, CIFAR-10 Batch 4:  cost is:  0.00347151
# accuracy is:  0.642
# Epoch 98, CIFAR-10 Batch 5:  cost is:  0.000666343
# accuracy is:  0.6512
# Epoch 99, CIFAR-10 Batch 1:  cost is:  0.00325836
# accuracy is:  0.6586
# Epoch 99, CIFAR-10 Batch 2:  cost is:  0.00163321
# accuracy is:  0.633
# Epoch 99, CIFAR-10 Batch 3:  cost is:  0.00144057
# accuracy is:  0.6482
# Epoch 99, CIFAR-10 Batch 4:  cost is:  0.000397236
# accuracy is:  0.6478
# Epoch 99, CIFAR-10 Batch 5:  cost is:  0.00609588
# accuracy is:  0.6476
# Epoch 100, CIFAR-10 Batch 1:  cost is:  0.0441833
# accuracy is:  0.6536
# Epoch 100, CIFAR-10 Batch 2:  cost is:  0.00319657
# accuracy is:  0.6446
# Epoch 100, CIFAR-10 Batch 3:  cost is:  0.00291195
# accuracy is:  0.6544
# Epoch 100, CIFAR-10 Batch 4:  cost is:  0.00157271
# accuracy is:  0.6404
# Epoch 100, CIFAR-10 Batch 5:  cost is:  0.000789448
# accuracy is:  0.6422

# %% [markdown]
# # 检查点
#
# 模型已保存到本地。
#
# ## 测试模型
#
# 利用测试数据集测试你的模型。这将是最终的准确率。你的准确率应该高于 50%。如果没达到，请继续调整模型结构和参数。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.6431962025316456

# %% [markdown]
# ## 为何准确率只有50-80%？
#
# 你可能想问，为何准确率不能更高了？首先，对于简单的 CNN 网络来说，50% 已经不低了。纯粹猜测的准确率为10%。但是，你可能注意到有人的准确率[远远超过 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130)。这是因为我们还没有介绍所有的神经网络知识。我们还需要掌握一些其他技巧。
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。将 notebook 文件另存为“dlnd_image_classification.ipynb”，再在目录 "File" -> "Download as" 另存为 HTML 格式。请在提交的项目中包含 “helper.py” 和 “problem_unittests.py” 文件。
