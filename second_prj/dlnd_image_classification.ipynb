# %% [markdown]
# # 图像分类
#
# 在此项目中，你将对 [CIFAR-10 数据集](https://www.cs.toronto.edu/~kriz/cifar.html) 中的图片进行分类。该数据集包含飞机、猫狗和其他物体。你需要预处理这些图片，然后用所有样本训练一个卷积神经网络。图片需要标准化（normalized），标签需要采用 one-hot 编码。你需要应用所学的知识构建卷积的、最大池化（max pooling）、丢弃（dropout）和完全连接（fully connected）的层。最后，你需要在样本图片上看到神经网络的预测结果。
#
#
# ## 获取数据
#
# 请运行以下单元，以下载 [CIFAR-10 数据集（Python版）](https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz)。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
from urllib.request import urlretrieve
from os.path import isfile, isdir
from tqdm import tqdm
import problem_unittests as tests
import tarfile

cifar10_dataset_folder_path = 'cifar-10-batches-py'

# Use Floyd's cifar-10 dataset if present
floyd_cifar10_location = './input/cifar-10/python.tar.gz'
if isfile(floyd_cifar10_location):
    tar_gz_path = floyd_cifar10_location
else:
    tar_gz_path = 'cifar-10-python.tar.gz'

class DLProgress(tqdm):
    last_block = 0

    def hook(self, block_num=1, block_size=1, total_size=None):
        self.total = total_size
        self.update((block_num - self.last_block) * block_size)
        self.last_block = block_num

if not isfile(tar_gz_path):
    with DLProgress(unit='B', unit_scale=True, miniters=1, desc='CIFAR-10 Dataset') as pbar:
        urlretrieve(
            'https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz',
            tar_gz_path,
            pbar.hook)

if not isdir(cifar10_dataset_folder_path):
    with tarfile.open(tar_gz_path) as tar:
        tar.extractall()
        tar.close()


tests.test_folder_path(cifar10_dataset_folder_path)
# Out:
# All files found!

# %% [markdown]
# ## 探索数据
#
# 该数据集分成了几部分／批次（batches），以免你的机器在计算时内存不足。CIFAR-10 数据集包含 5 个部分，名称分别为 `data_batch_1`、`data_batch_2`，以此类推。每个部分都包含以下某个类别的标签和图片：
#
# * 飞机
# * 汽车
# * 鸟类
# * 猫
# * 鹿
# * 狗
# * 青蛙
# * 马
# * 船只
# * 卡车
#
# 了解数据集也是对数据进行预测的必经步骤。你可以通过更改 `batch_id` 和 `sample_id` 探索下面的代码单元。`batch_id` 是数据集一个部分的 ID（1 到 5）。`sample_id` 是该部分中图片和标签对（label pair）的 ID。
#
# 问问你自己：“可能的标签有哪些？”、“图片数据的值范围是多少？”、“标签是按顺序排列，还是随机排列的？”。思考类似的问题，有助于你预处理数据，并使预测结果更准确。

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import helper
import numpy as np

# Explore the dataset
batch_id = 1
sample_id = 5
helper.display_stats(cifar10_dataset_folder_path, batch_id, sample_id)
# Out:
# Stats of batch 1:
# Samples: 10000
# Label Counts: {0: 1005, 1: 974, 2: 1032, 3: 1016, 4: 999, 5: 937, 6: 1030, 7: 1001, 8: 1025, 9: 981}
# First 20 Labels: [6, 9, 9, 4, 1, 1, 2, 7, 8, 3, 4, 7, 7, 2, 9, 9, 9, 3, 2, 6]
#
# Example of Image 5:
# Image - Min Value: 0 Max Value: 252
# Image - Shape: (32, 32, 3)
# Label - Label Id: 1 Name: automobile

# %% [markdown]
# ## 实现预处理函数
#
# ### 标准化
#
# 在下面的单元中，实现 `normalize` 函数，传入图片数据 `x`，并返回标准化 Numpy 数组。值应该在 0 到 1 的范围内（含 0 和 1）。返回对象应该和 `x` 的形状一样。

# %%
def normalize(x):
    """
    Normalize a list of sample image data in the range of 0 to 1
    : x: List of image data.  The image shape is (32, 32, 3)
    : return: Numpy array of normalize data
    """
    # TODO: Implement Function
    # so: 0-1 norm
    xmax = np.max(x)
    xmin = np.min(x)
    norm = (x - xmin)/(xmax - xmin)
    return norm


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_normalize(normalize)
# Out:
# Tests Passed

# %% [markdown]
# ### One-hot 编码
#
# 和之前的代码单元一样，你将为预处理实现一个函数。这次，你将实现 `one_hot_encode` 函数。输入，也就是 `x`，是一个标签列表。实现该函数，以返回为 one_hot 编码的 Numpy 数组的标签列表。标签的可能值为 0 到 9。每次调用 `one_hot_encode` 时，对于每个值，one_hot 编码函数应该返回相同的编码。确保将编码映射保存到该函数外面。
#
# 提示：不要重复发明轮子。

# %%
def one_hot_encode(x):
    """
    One hot encode a list of sample labels. Return a one-hot encoded vector for each label.
    : x: List of sample Labels
    : return: Numpy array of one-hot encoded labels
    """
    # TODO: Implement Function
    # 0: 1000_0000_00
    # 1: 0100_0000_00
    # x = [3,6.0,8]
    onehot = np.zeros((len(x),10),dtype=float)
    for index,label in enumerate(x):
        onehot[index][label] = 1
    return onehot


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_one_hot_encode(one_hot_encode)
# Out:
# Tests Passed

# %% [markdown]
# ### 随机化数据
#
# 之前探索数据时，你已经了解到，样本的顺序是随机的。再随机化一次也不会有什么关系，但是对于这个数据集没有必要。

# %% [markdown]
# ## 预处理所有数据并保存
#
# 运行下方的代码单元，将预处理所有 CIFAR-10 数据，并保存到文件中。下面的代码还使用了 10% 的训练数据，用来验证。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Preprocess Training, Validation, and Testing Data
helper.preprocess_and_save_data(cifar10_dataset_folder_path, normalize, one_hot_encode)

# %% [markdown]
# # 检查点
#
# 这是你的第一个检查点。如果你什么时候决定再回到该记事本，或需要重新启动该记事本，你可以从这里开始。预处理的数据已保存到本地。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import pickle
import problem_unittests as tests
import helper

# Load the Preprocessed Validation data
valid_features, valid_labels = pickle.load(open('preprocess_validation.p', mode='rb'))

# %%
valid_features.dtype
# Out:
# dtype('float64')

# %%
valid_labels.dtype
# Out:
# dtype('float64')

# %% [markdown]
# ## 构建网络
#
# 对于该神经网络，你需要将每层都构建为一个函数。你看到的大部分代码都位于函数外面。要更全面地测试你的代码，我们需要你将每层放入一个函数中。这样使我们能够提供更好的反馈，并使用我们的统一测试检测简单的错误，然后再提交项目。
#
# >**注意**：如果你觉得每周很难抽出足够的时间学习这门课程，我们为此项目提供了一个小捷径。对于接下来的几个问题，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 程序包中的类来构建每个层级，但是“卷积和最大池化层级”部分的层级除外。TF Layers 和 Keras 及 TFLearn 层级类似，因此很容易学会。
#
# >但是，如果你想充分利用这门课程，请尝试自己解决所有问题，不使用 TF Layers 程序包中的任何类。你依然可以使用其他程序包中的类，这些类和你在 TF Layers 中的类名称是一样的！例如，你可以使用 TF Neural Network 版本的 `conv2d` 类 [tf.nn.conv2d](https://www.tensorflow.org/api_docs/python/tf/nn/conv2d)，而不是 TF Layers 版本的 `conv2d` 类 [tf.layers.conv2d](https://www.tensorflow.org/api_docs/python/tf/layers/conv2d)。
#
# 我们开始吧！
#
#
# ### 输入
#
# 神经网络需要读取图片数据、one-hot 编码标签和丢弃保留概率（dropout keep probability）。请实现以下函数：
#
# * 实现 `neural_net_image_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `image_shape` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "x" 命名
# * 实现 `neural_net_label_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)
#  * 使用 `n_classes` 设置形状，部分大小设为 `None`
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "y" 命名
# * 实现 `neural_net_keep_prob_input`
#  * 返回 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder)，用于丢弃保留概率
#  * 使用 [TF Placeholder](https://www.tensorflow.org/api_docs/python/tf/placeholder) 中的 TensorFlow `name` 参数对 TensorFlow 占位符 "keep_prob" 命名
#
# 这些名称将在项目结束时，用于加载保存的模型。
#
# 注意：TensorFlow 中的 `None` 表示形状可以是动态大小。

# %%
import tensorflow as tf

def neural_net_image_input(image_shape):
    """
    Return a Tensor for a batch of image input
    : image_shape: Shape of the images
    : return: Tensor for image input.
    """
    # TODO: Implement Function
    image_shape = (None,) + image_shape
    image = tf.placeholder(dtype=tf.float32,shape=image_shape,name="x")
    return image


def neural_net_label_input(n_classes):
    """
    Return a Tensor for a batch of label input
    : n_classes: Number of classes
    : return: Tensor for label input.
    """
    # TODO: Implement Function
    label_shape = (None,n_classes)
    label = tf.placeholder(dtype=tf.float32,shape=label_shape,name="y")
    return label


def neural_net_keep_prob_input():
    """
    Return a Tensor for keep probability
    : return: Tensor for keep probability.
    """
    # TODO: Implement Function
    return tf.placeholder(dtype=tf.float32,shape=None,name="keep_prob")


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tf.reset_default_graph()
tests.test_nn_image_inputs(neural_net_image_input)
tests.test_nn_label_inputs(neural_net_label_input)
tests.test_nn_keep_prob_inputs(neural_net_keep_prob_input)
# Out:
# Image Input Tests Passed.
# Label Input Tests Passed.
# Keep Prob Tests Passed.

# %% [markdown]
# ### 卷积和最大池化层
#
# 卷积层级适合处理图片。对于此代码单元，你应该实现函数 `conv2d_maxpool` 以便应用卷积然后进行最大池化：
#
# * 使用 `conv_ksize`、`conv_num_outputs` 和 `x_tensor` 的形状创建权重（weight）和偏置（bias）。
# * 使用权重和 `conv_strides` 对 `x_tensor` 应用卷积。
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
# * 添加偏置
# * 向卷积中添加非线性激活（nonlinear activation）
# * 使用 `pool_ksize` 和 `pool_strides` 应用最大池化
#  * 建议使用我们建议的间距（padding），当然也可以使用任何其他间距。
#
# **注意**：对于**此层**，**请勿使用** [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers)，但是仍然可以使用 TensorFlow 的 [Neural Network](https://www.tensorflow.org/api_docs/python/tf/nn) 包。对于所有**其他层**，你依然可以使用快捷方法。

# %%
def conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides):
    """
    Apply convolution then max pooling to x_tensor
    :param x_tensor: TensorFlow Tensor
    :param conv_num_outputs: Number of outputs for the convolutional layer
    :param conv_ksize: kernal size 2-D Tuple for the convolutional layer
    :param conv_strides: Stride 2-D Tuple for convolution
    :param pool_ksize: kernal size 2-D Tuple for pool
    :param pool_strides: Stride 2-D Tuple for pool
    : return: A tensor that represents convolution and max pooling of x_tensor
    """
    # TODO: Implement Function
    # conv2d
    conv2d_shape = conv_ksize + (x_tensor.get_shape().as_list()[-1],conv_num_outputs)
    conv2d_strides = (1,) + conv_strides + (1,)
    print("conv2d_shape: ", conv2d_shape)
    print("conv2d_strides: ", conv2d_strides)
    std = 0.1
    kernel = tf.Variable(tf.truncated_normal(shape=conv2d_shape,stddev=std,dtype=tf.float32))
    bias = tf.zeros(conv_num_outputs,dtype=tf.float32)
    conv2d = tf.nn.bias_add(tf.nn.conv2d(x_tensor,kernel,conv2d_strides,padding="SAME"),bias)
    maxpool_ksize = (1,) + pool_ksize + (1,)
    maxpool_strides = (1,) + pool_strides + (1,)
    print("maxpool_ksize: ", maxpool_ksize)
    print("maxpool_strides: ", maxpool_strides)
    result = tf.nn.max_pool(conv2d,maxpool_ksize,maxpool_strides,padding="SAME")
    activate = tf.nn.relu(result)
    return activate 


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_con_pool(conv2d_maxpool)
# Out:
# conv2d_shape:  (2, 2, 5, 10)
# conv2d_strides:  (1, 4, 4, 1)
# maxpool_ksize:  (1, 2, 2, 1)
# maxpool_strides:  (1, 2, 2, 1)
# Tests Passed

# %% [markdown]
# ### 扁平化层
#
# 实现 `flatten` 函数，将 `x_tensor` 的维度从四维张量（4-D tensor）变成二维张量。输出应该是形状（*部分大小（Batch Size）*，*扁平化图片大小（Flattened Image Size）*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
from functools import reduce
def flatten(x_tensor):
    """
    Flatten x_tensor to (Batch Size, Flattened Image Size)
    : x_tensor: A tensor of size (Batch Size, ...), where ... are the image dimensions.
    : return: A tensor of size (Batch Size, Flattened Image Size).
    """
    # TODO: Implement Function
    shapelist = x_tensor.get_shape().as_list()
    batchsize = shapelist[0]
    flatten_size = reduce(lambda x,y:x*y,shapelist[1:])
    reshape = (-1,flatten_size) # should write -1, not None
    print(reshape)
    return tf.reshape(x_tensor,shape=reshape)


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_flatten(flatten)
# Out:
# (-1, 1800)
# Tests Passed

# %% [markdown]
# ### 全连接层
#
# 实现 `fully_conn` 函数，以向 `x_tensor` 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。

# %%
def fully_conn(x_tensor, num_outputs):
    """
    Apply a fully connected layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    # after flatten process
    x_dim = x_tensor.get_shape().as_list()[1]
    num_records = x_tensor.get_shape().as_list()[0]
    std = 0.1
    fc_w = tf.Variable(tf.truncated_normal(shape=(x_dim,num_outputs),stddev=std,dtype=tf.float32))
    fc_b = tf.Variable(tf.zeros(num_outputs))
    fc = tf.nn.bias_add(tf.matmul(x_tensor,fc_w),fc_b)
    activate = tf.nn.relu(fc)
    return activate


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_fully_conn(fully_conn)
# Out:
# Tests Passed

# %% [markdown]
# ### 输出层
#
# 实现 `output` 函数，向 x_tensor 应用完全连接的层级，形状为（*部分大小（Batch Size）*，*num_outputs*）。快捷方法：对于此层，你可以使用 [TensorFlow Layers](https://www.tensorflow.org/api_docs/python/tf/layers) 或 [TensorFlow Layers (contrib)](https://www.tensorflow.org/api_guides/python/contrib.layers) 包中的类。如果你想要更大挑战，可以仅使用其他 TensorFlow 程序包。
#
# **注意**：该层级不应应用 Activation、softmax 或交叉熵（cross entropy）。

# %%
def output(x_tensor, num_outputs):
    """
    Apply a output layer to x_tensor using weight and bias
    : x_tensor: A 2-D tensor where the first dimension is batch size.
    : num_outputs: The number of output that the new tensor should be.
    : return: A 2-D tensor where the second dimension is num_outputs.
    """
    # TODO: Implement Function
    x_dim = x_tensor.get_shape().as_list()[1]
    num_records = x_tensor.get_shape().as_list()[0]
    std = 0.1
    fc_w = tf.Variable(tf.truncated_normal((x_dim,num_outputs),stddev=std,dtype=tf.float32))
    fc_b = tf.Variable(tf.zeros(num_outputs))
    fc = tf.nn.bias_add(tf.matmul(x_tensor,fc_w),fc_b)
    return fc


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_output(output)
# Out:
# Tests Passed

# %% [markdown]
# ### 创建卷积模型
#
# 实现函数 `conv_net`， 创建卷积神经网络模型。该函数传入一批图片 `x`，并输出对数（logits）。使用你在上方创建的层创建此模型：
#
# * 应用 1、2 或 3 个卷积和最大池化层（Convolution and Max Pool layers）
# * 应用一个扁平层（Flatten Layer）
# * 应用 1、2 或 3 个完全连接层（Fully Connected Layers）
# * 应用一个输出层（Output Layer）
# * 返回输出
# * 使用 `keep_prob` 向模型中的一个或多个层应用 [TensorFlow 的 Dropout](https://www.tensorflow.org/api_docs/python/tf/nn/dropout)

# %%
def conv_net(x, keep_prob):
    """
    Create a convolutional neural network model
    : x: Placeholder tensor that holds image data.
    : keep_prob: Placeholder tensor that hold dropout keep probability.
    : return: Tensor that represents logits
    """
    # TODO: Apply 1, 2, or 3 Convolution and Max Pool layers
    #    Play around with different number of outputs, kernel size and stride
    # Function Definition from Above:
    #    conv2d_maxpool(x_tensor, conv_num_outputs, conv_ksize, conv_strides, pool_ksize, pool_strides)
    conv2d_1 = conv2d_maxpool(x,32,(3,3),(1,1),(3,3),(2,2))
    conv2d_2 = conv2d_maxpool(conv2d_1,64,(3,3),(1,1),(3,3),(2,2))
    conv2d_3 = conv2d_maxpool(conv2d_2,128,(3,3),(1,1),(3,3),(2,2))

    # TODO: Apply a Flatten Layer
    # Function Definition from Above:
    #   flatten(x_tensor)
    flat = flatten(conv2d_3)

    # TODO: Apply 1, 2, or 3 Fully Connected Layers
    #    Play around with different number of outputs
    # Function Definition from Above:
    #   fully_conn(x_tensor, num_outputs)
    fc_1 = tf.nn.dropout(fully_conn(flat,512),keep_prob)
    fc_2 = tf.nn.dropout(fully_conn(fc_1,256),keep_prob)
    fc_3 = tf.nn.dropout(fully_conn(fc_2,128),keep_prob)
    
    # TODO: Apply an Output Layer
    #    Set this to the number of classes
    # Function Definition from Above:
    #   output(x_tensor, num_outputs)
    out = output(fc_3,10)
    
    # TODO: return output
    return out


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""

##############################
## Build the Neural Network ##
##############################

# Remove previous weights, bias, inputs, etc..
tf.reset_default_graph()

# Inputs
x = neural_net_image_input((32, 32, 3))
y = neural_net_label_input(10)
keep_prob = neural_net_keep_prob_input()

# Model
logits = conv_net(x, keep_prob)

# Name logits Tensor, so that is can be loaded from disk after training
logits = tf.identity(logits, name='logits')

# Loss and Optimizer
cost = tf.reduce_mean(tf.nn.softmax_cross_entropy_with_logits(logits=logits, labels=y))
optimizer = tf.train.AdamOptimizer().minimize(cost)

# Accuracy
correct_pred = tf.equal(tf.argmax(logits, 1), tf.argmax(y, 1))
accuracy = tf.reduce_mean(tf.cast(correct_pred, tf.float32), name='accuracy')

tests.test_conv_net(conv_net)
# Out:
# conv2d_shape:  (3, 3, 3, 32)
# conv2d_strides:  (1, 1, 1, 1)
# maxpool_ksize:  (1, 3, 3, 1)
# maxpool_strides:  (1, 2, 2, 1)
# conv2d_shape:  (3, 3, 32, 64)
# conv2d_strides:  (1, 1, 1, 1)
# maxpool_ksize:  (1, 3, 3, 1)
# maxpool_strides:  (1, 2, 2, 1)
# conv2d_shape:  (3, 3, 64, 128)
# conv2d_strides:  (1, 1, 1, 1)
# maxpool_ksize:  (1, 3, 3, 1)
# maxpool_strides:  (1, 2, 2, 1)
# (-1, 2048)
# conv2d_shape:  (3, 3, 3, 32)
# conv2d_strides:  (1, 1, 1, 1)
# maxpool_ksize:  (1, 3, 3, 1)
# maxpool_strides:  (1, 2, 2, 1)
# conv2d_shape:  (3, 3, 32, 64)
# conv2d_strides:  (1, 1, 1, 1)
# maxpool_ksize:  (1, 3, 3, 1)
# maxpool_strides:  (1, 2, 2, 1)
# conv2d_shape:  (3, 3, 64, 128)
# conv2d_strides:  (1, 1, 1, 1)
# maxpool_ksize:  (1, 3, 3, 1)
# maxpool_strides:  (1, 2, 2, 1)
# (-1, 2048)
# Neural Network Built!

# %% [markdown]
# ## 训练神经网络
#
# ### 单次优化
#
# 实现函数 `train_neural_network` 以进行单次优化（single optimization）。该优化应该使用 `optimizer` 优化 `session`，其中 `feed_dict` 具有以下参数：
#
# * `x` 表示图片输入
# * `y` 表示标签
# * `keep_prob` 表示丢弃的保留率
#
# 每个部分都会调用该函数，所以 `tf.global_variables_initializer()` 已经被调用。
#
# 注意：不需要返回任何内容。该函数只是用来优化神经网络。

# %%
def train_neural_network(session, optimizer, keep_probability, feature_batch, label_batch):
    """
    Optimize the session on a batch of images and labels
    : session: Current TensorFlow session
    : optimizer: TensorFlow optimizer function
    : keep_probability: keep probability
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    """
    # TODO: Implement Function
    session.run(optimizer,feed_dict={
        x:feature_batch,
        y:label_batch,
        keep_prob:keep_probability
        
    })
    
"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_train_nn(train_neural_network)
# Out:
# Tests Passed

# %% [markdown]
# ### 显示数据
#
# 实现函数 `print_stats` 以输出损失和验证准确率。使用全局变量 `valid_features` 和 `valid_labels` 计算验证准确率。使用保留率 `1.0` 计算损失和验证准确率（loss and validation accuracy）。

# %%
def print_stats(session, feature_batch, label_batch, cost, accuracy):
    """
    Print information about loss and validation accuracy
    : session: Current TensorFlow session
    : feature_batch: Batch of Numpy image data
    : label_batch: Batch of Numpy label data
    : cost: TensorFlow cost function
    : accuracy: TensorFlow accuracy function
    """
    # TODO: Implement Function
    cost = session.run(cost,feed_dict={
        x:feature_batch,
        y:label_batch,
        keep_prob:1.0
    })
    global valid_features
    global valid_labels
    accuracy = session.run(accuracy,feed_dict={
        x:valid_features,
        y:valid_labels,
        keep_prob:1.0
    })
    
    print("cost is: ",cost)
    print("accuracy is: ",accuracy)

# %% [markdown]
# ### 超参数
#
# 调试以下超参数：
# * 设置 `epochs` 表示神经网络停止学习或开始过拟合的迭代次数
# * 设置 `batch_size`，表示机器内存允许的部分最大体积。大部分人设为以下常见内存大小：
#
#  * 64
#  * 128
#  * 256
#  * ...
# * 设置 `keep_probability` 表示使用丢弃时保留节点的概率

# %%
# TODO: Tune Parameters
epochs = 100
batch_size = 128
keep_probability = 0.8

# %% [markdown]
# ### 在单个 CIFAR-10 部分上训练
#
# 我们先用单个部分，而不是用所有的 CIFAR-10 批次训练神经网络。这样可以节省时间，并对模型进行迭代，以提高准确率。最终验证准确率达到 50% 或以上之后，在下一部分对所有数据运行模型。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
print('Checking the Training on a Single Batch...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        batch_i = 1
        for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
            train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
        print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
        print_stats(sess, batch_features, batch_labels, cost, accuracy)
# Out:
# Checking the Training on a Single Batch...
# Epoch  1, CIFAR-10 Batch 1:  cost is:  1.93413
# accuracy is:  0.3428
# Epoch  2, CIFAR-10 Batch 1:  cost is:  1.75055
# accuracy is:  0.4246
# Epoch  3, CIFAR-10 Batch 1:  cost is:  1.49627
# accuracy is:  0.4596
# Epoch  4, CIFAR-10 Batch 1:  cost is:  1.29439
# accuracy is:  0.5114
# Epoch  5, CIFAR-10 Batch 1:  cost is:  1.15482
# accuracy is:  0.5264
# Epoch  6, CIFAR-10 Batch 1:  cost is:  1.01982
# accuracy is:  0.5516
# Epoch  7, CIFAR-10 Batch 1:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-139-0ebd1bbc35ad> in <module>()
#      13             train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
#      14         print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
# ---> 15         print_stats(sess, batch_features, batch_labels, cost, accuracy)
#
# <ipython-input-137-5b74ecdea7f2> in print_stats(session, feature_batch, label_batch, cost, accuracy)
#      19         x:valid_features,
#      20         y:valid_labels,
# ---> 21         keep_prob:1.0
#      22     })
#      23
#
# ~/anaconda2/envs/dlnd35/lib/python3.5/site-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     765     try:
#     766       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 767                          run_metadata_ptr)
#     768       if run_metadata:
#     769         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# ~/anaconda2/envs/dlnd35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#     963     if final_fetches or final_targets:
#     964       results = self._do_run(handle, final_targets, final_fetches,
# --> 965                              feed_dict_string, options, run_metadata)
#     966     else:
#     967       results = []
#
# ~/anaconda2/envs/dlnd35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1013     if handle is None:
#    1014       return self._do_call(_run_fn, self._session, feed_dict, fetch_list,
# -> 1015                            target_list, options, run_metadata)
#    1016     else:
#    1017       return self._do_call(_prun_fn, self._session, handle, feed_dict,
#
# ~/anaconda2/envs/dlnd35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1020   def _do_call(self, fn, *args):
#    1021     try:
# -> 1022       return fn(*args)
#    1023     except errors.OpError as e:
#    1024       message = compat.as_text(e.message)
#
# ~/anaconda2/envs/dlnd35/lib/python3.5/site-packages/tensorflow/python/client/session.py in _run_fn(session, feed_dict, fetch_list, target_list, options, run_metadata)
#    1002         return tf_session.TF_Run(session, options,
#    1003                                  feed_dict, fetch_list, target_list,
# -> 1004                                  status, run_metadata)
#    1005
#    1006     def _prun_fn(session, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:

# %% [markdown]
# ### 完全训练模型
#
# 现在，单个 CIFAR-10 部分的准确率已经不错了，试试所有五个部分吧。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_model_path = './image_classification'

print('Training...')
with tf.Session() as sess:
    # Initializing the variables
    sess.run(tf.global_variables_initializer())
    
    # Training cycle
    for epoch in range(epochs):
        # Loop over all batches
        n_batches = 5
        for batch_i in range(1, n_batches + 1):
            for batch_features, batch_labels in helper.load_preprocess_training_batch(batch_i, batch_size):
                train_neural_network(sess, optimizer, keep_probability, batch_features, batch_labels)
            print('Epoch {:>2}, CIFAR-10 Batch {}:  '.format(epoch + 1, batch_i), end='')
            print_stats(sess, batch_features, batch_labels, cost, accuracy)
            
    # Save Model
    saver = tf.train.Saver()
    save_path = saver.save(sess, save_model_path)
# Out:
# Training...
# Epoch  1, CIFAR-10 Batch 1:  cost is:  2.02189
# accuracy is:  0.3126
# Epoch  1, CIFAR-10 Batch 2:  cost is:  1.54863
# accuracy is:  0.4114
# Epoch  1, CIFAR-10 Batch 3:  cost is:  1.27364
# accuracy is:  0.4652
# Epoch  1, CIFAR-10 Batch 4:  cost is:  1.33766
# accuracy is:  0.506
# Epoch  1, CIFAR-10 Batch 5:  cost is:  1.27247
# accuracy is:  0.5454
# Epoch  2, CIFAR-10 Batch 1:  cost is:  1.16951
# accuracy is:  0.5604
# Epoch  2, CIFAR-10 Batch 2:  cost is:  1.09954
# accuracy is:  0.5788
# Epoch  2, CIFAR-10 Batch 3:  cost is:  0.924314
# accuracy is:  0.5812
# Epoch  2, CIFAR-10 Batch 4:  cost is:  0.942298
# accuracy is:  0.5916
# Epoch  2, CIFAR-10 Batch 5:  cost is:  0.977131
# accuracy is:  0.6286
# Epoch  3, CIFAR-10 Batch 1:  cost is:  0.859073
# accuracy is:  0.637
# Epoch  3, CIFAR-10 Batch 2:  cost is:  0.638763
# accuracy is:  0.632
# Epoch  3, CIFAR-10 Batch 3:  cost is:  0.749377
# accuracy is:  0.6168
# Epoch  3, CIFAR-10 Batch 4:  cost is:  0.713403
# accuracy is:  0.656
# Epoch  3, CIFAR-10 Batch 5:  cost is:  0.758828
# accuracy is:  0.658
# Epoch  4, CIFAR-10 Batch 1:  cost is:  0.684063
# accuracy is:  0.6584
# Epoch  4, CIFAR-10 Batch 2:  cost is:  0.527138
# accuracy is:  0.6732
# Epoch  4, CIFAR-10 Batch 3:  cost is:  0.474769
# accuracy is:  0.6768
# Epoch  4, CIFAR-10 Batch 4:  cost is:  0.534886
# accuracy is:  0.6868
# Epoch  4, CIFAR-10 Batch 5:  cost is:  0.569608
# accuracy is:  0.6922
# Epoch  5, CIFAR-10 Batch 1:  cost is:  0.542743
# accuracy is:  0.6902
# Epoch  5, CIFAR-10 Batch 2:  cost is:  0.291496
# accuracy is:  0.6952
# Epoch  5, CIFAR-10 Batch 3:  cost is:  0.318011
# accuracy is:  0.715
# Epoch  5, CIFAR-10 Batch 4:  cost is:  0.368341
# accuracy is:  0.7082
# Epoch  5, CIFAR-10 Batch 5:  cost is:  0.402302
# accuracy is:  0.7056
# Epoch  6, CIFAR-10 Batch 1:  cost is:  0.491412
# accuracy is:  0.718
# Epoch  6, CIFAR-10 Batch 2:  cost is:  0.284485
# accuracy is:  0.707
# Epoch  6, CIFAR-10 Batch 3:  cost is:  0.318696
# accuracy is:  0.68
# Epoch  6, CIFAR-10 Batch 4:  cost is:  0.280236
# accuracy is:  0.7192
# Epoch  6, CIFAR-10 Batch 5:  cost is:  0.353413
# accuracy is:  0.7066
# Epoch  7, CIFAR-10 Batch 1:  cost is:  0.391041
# accuracy is:  0.7186
# Epoch  7, CIFAR-10 Batch 2:  cost is:  0.183989
# accuracy is:  0.7124
# Epoch  7, CIFAR-10 Batch 3:  cost is:  0.172302
# accuracy is:  0.7212
# Epoch  7, CIFAR-10 Batch 4:  cost is:  0.224505
# accuracy is:  0.719
# Epoch  7, CIFAR-10 Batch 5:  cost is:  0.243057
# accuracy is:  0.7314
# Epoch  8, CIFAR-10 Batch 1:  cost is:  0.38587
# accuracy is:  0.7238
# Epoch  8, CIFAR-10 Batch 2:  cost is:  0.155158
# accuracy is:  0.727
# Epoch  8, CIFAR-10 Batch 3:  cost is:  0.139753
# accuracy is:  0.7264
# Epoch  8, CIFAR-10 Batch 4:  cost is:  0.140828
# accuracy is:  0.7314
# Epoch  8, CIFAR-10 Batch 5:  cost is:  0.194331
# accuracy is:  0.7306
# Epoch  9, CIFAR-10 Batch 1:  cost is:  0.301952
# accuracy is:  0.7312
# Epoch  9, CIFAR-10 Batch 2:  cost is:  0.128926
# accuracy is:  0.733
# Epoch  9, CIFAR-10 Batch 3:  cost is:  0.104296
# accuracy is:  0.7378
# Epoch  9, CIFAR-10 Batch 4:  cost is:  0.178859
# accuracy is:  0.7272
# Epoch  9, CIFAR-10 Batch 5:  cost is:  0.1187
# accuracy is:  0.7202
# Epoch 10, CIFAR-10 Batch 1:  cost is:  0.193442
# accuracy is:  0.743
# Epoch 10, CIFAR-10 Batch 2:  cost is:  0.15254
# accuracy is:  0.7184
# Epoch 10, CIFAR-10 Batch 3:  cost is:  0.0839345
# accuracy is:  0.737
# Epoch 10, CIFAR-10 Batch 4:  cost is:  0.128533
# accuracy is:  0.7222
# Epoch 10, CIFAR-10 Batch 5:  cost is:  0.0986796
# accuracy is:  0.719
# Epoch 11, CIFAR-10 Batch 1:  cost is:  0.13789
# accuracy is:  0.7408
# Epoch 11, CIFAR-10 Batch 2:  cost is:  0.104282
# accuracy is:  0.7052
# Epoch 11, CIFAR-10 Batch 3:  cost is:  0.0859658
# accuracy is:  0.733
# Epoch 11, CIFAR-10 Batch 4:  cost is:  0.129263
# accuracy is:  0.7188
# Epoch 11, CIFAR-10 Batch 5:  cost is:  0.103905
# accuracy is:  0.7222
# Epoch 12, CIFAR-10 Batch 1:  cost is:  0.117343
# accuracy is:  0.739
# Epoch 12, CIFAR-10 Batch 2:  cost is:  0.0597829
# accuracy is:  0.7252
# Epoch 12, CIFAR-10 Batch 3:  cost is:  0.0603369
# accuracy is:  0.7302
# Epoch 12, CIFAR-10 Batch 4:  cost is:  0.0905907
# accuracy is:  0.733
# Epoch 12, CIFAR-10 Batch 5:  cost is:  0.0326086
# accuracy is:  0.7338
# Epoch 13, CIFAR-10 Batch 1:  cost is:  0.0643189
# accuracy is:  0.7274
# Epoch 13, CIFAR-10 Batch 2:  cost is:  0.0398058
# accuracy is:  0.7068
# Epoch 13, CIFAR-10 Batch 3:  cost is:  0.0713842
# accuracy is:  0.7362
# Epoch 13, CIFAR-10 Batch 4:  cost is:  0.0772477
# accuracy is:  0.7296
# Epoch 13, CIFAR-10 Batch 5:  cost is:  0.0457697
# accuracy is:  0.7292
# Epoch 14, CIFAR-10 Batch 1:  cost is:  0.0543923
# accuracy is:  0.7214
# Epoch 14, CIFAR-10 Batch 2:  cost is:  0.0387893
# accuracy is:  0.7306
# Epoch 14, CIFAR-10 Batch 3:  cost is:  0.0183072
# accuracy is:  0.7318
# Epoch 14, CIFAR-10 Batch 4:  cost is:  0.0967837
# accuracy is:  0.7086
# Epoch 14, CIFAR-10 Batch 5:  cost is:  0.063571
# accuracy is:  0.714
# Epoch 15, CIFAR-10 Batch 1:  cost is:  0.0603627
# accuracy is:  0.7292
# Epoch 15, CIFAR-10 Batch 2:  cost is:  0.0223019
# accuracy is:  0.7352
# Epoch 15, CIFAR-10 Batch 3:  cost is:  0.0213462
# accuracy is:  0.7376
# Epoch 15, CIFAR-10 Batch 4:  cost is:  0.0346873
# accuracy is:  0.72
# Epoch 15, CIFAR-10 Batch 5:  cost is:  0.0214069
# accuracy is:  0.727
# Epoch 16, CIFAR-10 Batch 1:  cost is:  0.0358846
# accuracy is:  0.7202
# Epoch 16, CIFAR-10 Batch 2:  cost is:  0.0527704
# accuracy is:  0.7196
# Epoch 16, CIFAR-10 Batch 3:  cost is:  0.0185301
# accuracy is:  0.7176
# Epoch 16, CIFAR-10 Batch 4:  cost is:  0.0436015
# accuracy is:  0.7248
# Epoch 16, CIFAR-10 Batch 5:  cost is:  0.0131519
# accuracy is:  0.727
# Epoch 17, CIFAR-10 Batch 1:  cost is:  0.0230074
# accuracy is:  0.7322
# Epoch 17, CIFAR-10 Batch 2:  cost is:  0.022522
# accuracy is:  0.729
# Epoch 17, CIFAR-10 Batch 3:  cost is:  0.0246234
# accuracy is:  0.715
# Epoch 17, CIFAR-10 Batch 4:  cost is:  0.0300488
# accuracy is:  0.7168
# Epoch 17, CIFAR-10 Batch 5:  cost is:  0.0170082
# accuracy is:  0.7356
# Epoch 18, CIFAR-10 Batch 1:  cost is:  0.0650113
# accuracy is:  0.725
# Epoch 18, CIFAR-10 Batch 2:  cost is:  0.008824
# accuracy is:  0.7312
# Epoch 18, CIFAR-10 Batch 3:  cost is:  0.0129082
# accuracy is:  0.7068
# Epoch 18, CIFAR-10 Batch 4:  cost is:  0.0144542
# accuracy is:  0.733
# Epoch 18, CIFAR-10 Batch 5:  cost is:  0.0076171
# accuracy is:  0.7364
# Epoch 19, CIFAR-10 Batch 1:  cost is:  0.0499144
# accuracy is:  0.7146
# Epoch 19, CIFAR-10 Batch 2:  cost is:  0.0154543
# accuracy is:  0.724
# Epoch 19, CIFAR-10 Batch 3:  cost is:  0.007203
# accuracy is:  0.7238
# Epoch 19, CIFAR-10 Batch 4:  cost is:  0.0118021
# accuracy is:  0.7372
# Epoch 19, CIFAR-10 Batch 5:  cost is:  0.010616
# accuracy is:  0.7252
# Epoch 20, CIFAR-10 Batch 1:  cost is:  0.0283638
# accuracy is:  0.74
# Epoch 20, CIFAR-10 Batch 2:  cost is:  0.0151727
# accuracy is:  0.7236
# Epoch 20, CIFAR-10 Batch 3:  cost is:  0.00510889
# accuracy is:  0.723
# Epoch 20, CIFAR-10 Batch 4:  cost is:  0.0272735
# accuracy is:  0.7408
# Epoch 20, CIFAR-10 Batch 5:  cost is:  0.0124117
# accuracy is:  0.7304
# Epoch 21, CIFAR-10 Batch 1:  cost is:  0.0153979
# accuracy is:  0.7398
# Epoch 21, CIFAR-10 Batch 2:  cost is:  0.00612948
# accuracy is:  0.7386
# Epoch 21, CIFAR-10 Batch 3:  cost is:  0.00185994
# accuracy is:  0.7294
# Epoch 21, CIFAR-10 Batch 4:  cost is:  0.00419542
# accuracy is:  0.7468
# Epoch 21, CIFAR-10 Batch 5:  cost is:  0.00855869
# accuracy is:  0.7296
# Epoch 22, CIFAR-10 Batch 1:  cost is:  0.0140036
# accuracy is:  0.7302
# Epoch 22, CIFAR-10 Batch 2:  cost is:  0.00565181
# accuracy is:  0.7126
# Epoch 22, CIFAR-10 Batch 3:  cost is:  0.0065163
# accuracy is:  0.721
# Epoch 22, CIFAR-10 Batch 4:  cost is:  0.0042772
# accuracy is:  0.7412
# Epoch 22, CIFAR-10 Batch 5:  cost is:  0.00942561
# accuracy is:  0.7382
# Epoch 23, CIFAR-10 Batch 1:  cost is:  0.014244
# accuracy is:  0.7394
# Epoch 23, CIFAR-10 Batch 2:  cost is:  0.00388914
# accuracy is:  0.7364
# Epoch 23, CIFAR-10 Batch 3:  cost is:  0.00394077
# accuracy is:  0.7246
# Epoch 23, CIFAR-10 Batch 4:  cost is:  0.00601497
# accuracy is:  0.7312
# Epoch 23, CIFAR-10 Batch 5:  cost is:  0.0287752
# accuracy is:  0.7456
# Epoch 24, CIFAR-10 Batch 1:  cost is:  0.0119549
# accuracy is:  0.7338
# Epoch 24, CIFAR-10 Batch 2:  cost is:  0.00442402
# accuracy is:  0.7264
# Epoch 24, CIFAR-10 Batch 3:  cost is:  0.00939279
# accuracy is:  0.7354
# Epoch 24, CIFAR-10 Batch 4:  cost is:  0.00787468
# accuracy is:  0.7428
# Epoch 24, CIFAR-10 Batch 5:  cost is:  0.00770061
# accuracy is:  0.7408
# Epoch 25, CIFAR-10 Batch 1:  cost is:  0.0335435
# accuracy is:  0.7228
# Epoch 25, CIFAR-10 Batch 2:  cost is:  0.00426049
# accuracy is:  0.7438
# Epoch 25, CIFAR-10 Batch 3:  cost is:  0.0111462
# accuracy is:  0.7404
# Epoch 25, CIFAR-10 Batch 4:  cost is:  0.00513496
# accuracy is:  0.7442
# Epoch 25, CIFAR-10 Batch 5:  cost is:  0.00233949
# accuracy is:  0.7486
# Epoch 26, CIFAR-10 Batch 1:  cost is:  0.018724
# accuracy is:  0.7452
# Epoch 26, CIFAR-10 Batch 2:  cost is:  0.00454518
# accuracy is:  0.7382
# Epoch 26, CIFAR-10 Batch 3:  cost is:  0.00596496
# accuracy is:  0.75
# Epoch 26, CIFAR-10 Batch 4:  cost is:  0.00243347
# accuracy is:  0.728
# Epoch 26, CIFAR-10 Batch 5:  cost is:  0.00381598
# accuracy is:  0.7412
# Epoch 27, CIFAR-10 Batch 1:  cost is:  0.00589596
# accuracy is:  0.746
# Epoch 27, CIFAR-10 Batch 2:  cost is:  0.00344921
# accuracy is:  0.7322
# Epoch 27, CIFAR-10 Batch 3:  cost is:  0.0173759
# accuracy is:  0.7518
# Epoch 27, CIFAR-10 Batch 4:  cost is:  0.00655591
# accuracy is:  0.7322
# Epoch 27, CIFAR-10 Batch 5:  cost is:  0.0015838
# accuracy is:  0.7306
# Epoch 28, CIFAR-10 Batch 1:  cost is:  0.00375873
# accuracy is:  0.7422
# Epoch 28, CIFAR-10 Batch 2:  cost is:  0.00608769
# accuracy is:  0.732
# Epoch 28, CIFAR-10 Batch 3:  cost is:  0.0148298
# accuracy is:  0.7502
# Epoch 28, CIFAR-10 Batch 4:  cost is:  0.0105751
# accuracy is:  0.7332
# Epoch 28, CIFAR-10 Batch 5:  cost is:  0.00389194
# accuracy is:  0.7398
# Epoch 29, CIFAR-10 Batch 1:  cost is:  0.00290986
# accuracy is:  0.7484
# Epoch 29, CIFAR-10 Batch 2:  cost is:  0.00254225
# accuracy is:  0.7408
# Epoch 29, CIFAR-10 Batch 3:  cost is:  0.0113659
# accuracy is:  0.7446
# Epoch 29, CIFAR-10 Batch 4:  cost is:  0.00758696
# accuracy is:  0.7442
# Epoch 29, CIFAR-10 Batch 5:  cost is:  0.00661291
# accuracy is:  0.7254
# Epoch 30, CIFAR-10 Batch 1:  cost is:  0.00396351
# accuracy is:  0.743
# Epoch 30, CIFAR-10 Batch 2:  cost is:  0.00648142
# accuracy is:  0.7348
# Epoch 30, CIFAR-10 Batch 3:  cost is:  0.00329612
# accuracy is:  0.7442
# Epoch 30, CIFAR-10 Batch 4:  cost is:  0.00637915
# accuracy is:  0.7322
# Epoch 30, CIFAR-10 Batch 5:  cost is:  0.000656356
# accuracy is:  0.7472
# Epoch 31, CIFAR-10 Batch 1:  cost is:  0.00166142
# accuracy is:  0.7374
# Epoch 31, CIFAR-10 Batch 2:  cost is:  0.0019127
# accuracy is:  0.744
# Epoch 31, CIFAR-10 Batch 3:  cost is:  0.000595137
# accuracy is:  0.7398
# Epoch 31, CIFAR-10 Batch 4:  cost is:  0.00554634
# accuracy is:  0.712
# Epoch 31, CIFAR-10 Batch 5:  cost is:  0.00225931
# accuracy is:  0.756
# Epoch 32, CIFAR-10 Batch 1:  cost is:  0.00193864
# accuracy is:  0.7454
# Epoch 32, CIFAR-10 Batch 2:  cost is:  0.0040821
# accuracy is:  0.7428
# Epoch 32, CIFAR-10 Batch 3:  cost is:  0.0085374
# accuracy is:  0.7518
# Epoch 32, CIFAR-10 Batch 4:  cost is:  0.00927325
# accuracy is:  0.7146
# Epoch 32, CIFAR-10 Batch 5:  cost is:  0.00559823
# accuracy is:  0.738
# Epoch 33, CIFAR-10 Batch 1:  cost is:  0.000917846
# accuracy is:  0.7504
# Epoch 33, CIFAR-10 Batch 2:  cost is:  0.00424828
# accuracy is:  0.7426
# Epoch 33, CIFAR-10 Batch 3:  cost is:  0.000549312
# accuracy is:  0.759
# Epoch 33, CIFAR-10 Batch 4:  cost is:  0.00916968
# accuracy is:  0.7238
# Epoch 33, CIFAR-10 Batch 5:  cost is:  0.00147125
# accuracy is:  0.7438
# Epoch 34, CIFAR-10 Batch 1:  cost is:  0.000764693
# accuracy is:  0.7436
# Epoch 34, CIFAR-10 Batch 2:  cost is:  0.00192414
# accuracy is:  0.7318
# Epoch 34, CIFAR-10 Batch 3:  cost is:  0.00158143
# accuracy is:  0.747
# Epoch 34, CIFAR-10 Batch 4:  cost is:  0.00113856
# accuracy is:  0.7236
# Epoch 34, CIFAR-10 Batch 5:  cost is:  0.00133721
# accuracy is:  0.7434
# Epoch 35, CIFAR-10 Batch 1:  cost is:  0.000251114
# accuracy is:  0.739
# Epoch 35, CIFAR-10 Batch 2:  cost is:  0.00281038
# accuracy is:  0.7364
# Epoch 35, CIFAR-10 Batch 3:  cost is:  0.000778096
# accuracy is:  0.7508
# Epoch 35, CIFAR-10 Batch 4:  cost is:  0.000311428
# accuracy is:  0.7302
# Epoch 35, CIFAR-10 Batch 5:  cost is:  0.000437169
# accuracy is:  0.7338
# Epoch 36, CIFAR-10 Batch 1:  cost is:  0.000661281
# accuracy is:  0.7356
# Epoch 36, CIFAR-10 Batch 2:  cost is:  0.00470952
# accuracy is:  0.7398
# Epoch 36, CIFAR-10 Batch 3:  cost is:  0.00154584
# accuracy is:  0.7516
# Epoch 36, CIFAR-10 Batch 4:  cost is:  0.00183431
# accuracy is:  0.7352
# Epoch 36, CIFAR-10 Batch 5:  cost is:  0.000332038
# accuracy is:  0.74
# Epoch 37, CIFAR-10 Batch 1:  cost is:  0.00308239
# accuracy is:  0.7422
# Epoch 37, CIFAR-10 Batch 2:  cost is:  0.00302943
# accuracy is:  0.717
# Epoch 37, CIFAR-10 Batch 3:  cost is:  0.00271465
# accuracy is:  0.7444
# Epoch 37, CIFAR-10 Batch 4:  cost is:  0.00063423
# accuracy is:  0.7292
# Epoch 37, CIFAR-10 Batch 5:  cost is:  0.00346993
# accuracy is:  0.738
# Epoch 38, CIFAR-10 Batch 1:  cost is:  0.00116529
# accuracy is:  0.7484
# Epoch 38, CIFAR-10 Batch 2:  cost is:  0.00561932
# accuracy is:  0.7416
# Epoch 38, CIFAR-10 Batch 3:  cost is:  0.00250774
# accuracy is:  0.755
# Epoch 38, CIFAR-10 Batch 4:  cost is:  0.00122771
# accuracy is:  0.7458
# Epoch 38, CIFAR-10 Batch 5:  cost is:  0.00146539
# accuracy is:  0.7418
# Epoch 39, CIFAR-10 Batch 1:  cost is:  0.00192578
# accuracy is:  0.7498
# Epoch 39, CIFAR-10 Batch 2:  cost is:  0.0015639
# accuracy is:  0.7214
# Epoch 39, CIFAR-10 Batch 3:  cost is:  0.00121087
# accuracy is:  0.7456
# Epoch 39, CIFAR-10 Batch 4:  cost is:  0.000692204
# accuracy is:  0.7496
# Epoch 39, CIFAR-10 Batch 5:  cost is:  0.000724556
# accuracy is:  0.749
# Epoch 40, CIFAR-10 Batch 1:  cost is:  0.000150267
# accuracy is:  0.7346
# Epoch 40, CIFAR-10 Batch 2:  cost is:  0.000695873
# accuracy is:  0.732
# Epoch 40, CIFAR-10 Batch 3:  cost is:  0.00412021
# accuracy is:  0.7482
# Epoch 40, CIFAR-10 Batch 4:  cost is:  0.0002114
# accuracy is:  0.7466
# Epoch 40, CIFAR-10 Batch 5:  cost is:  0.00341732
# accuracy is:  0.7464
# Epoch 41, CIFAR-10 Batch 1:  cost is:  0.00144516
# accuracy is:  0.7448
# Epoch 41, CIFAR-10 Batch 2:  cost is:  0.000580549
# accuracy is:  0.7356
# Epoch 41, CIFAR-10 Batch 3:  cost is:  0.0106508
# accuracy is:  0.7404
# Epoch 41, CIFAR-10 Batch 4:  cost is:  0.000375604
# accuracy is:  0.743
# Epoch 41, CIFAR-10 Batch 5:  cost is:  0.00476861
# accuracy is:  0.7372
# Epoch 42, CIFAR-10 Batch 1:  cost is:  0.0011112
# accuracy is:  0.7516
# Epoch 42, CIFAR-10 Batch 2:  cost is:  0.000296222
# accuracy is:  0.7344
# Epoch 42, CIFAR-10 Batch 3:  cost is:  0.000491332
# accuracy is:  0.7522
# Epoch 42, CIFAR-10 Batch 4:  cost is:  0.0143062
# accuracy is:  0.7416
# Epoch 42, CIFAR-10 Batch 5:  cost is:  0.000292132
# accuracy is:  0.738
# Epoch 43, CIFAR-10 Batch 1:  cost is:  0.00490378
# accuracy is:  0.745
# Epoch 43, CIFAR-10 Batch 2:  cost is:  0.00192904
# accuracy is:  0.7288
# Epoch 43, CIFAR-10 Batch 3:  cost is:  0.00111765
# accuracy is:  0.747
# Epoch 43, CIFAR-10 Batch 4:  cost is:  0.00208247
# accuracy is:  0.7372
# Epoch 43, CIFAR-10 Batch 5:  cost is:  0.00550607
# accuracy is:  0.753
# Epoch 44, CIFAR-10 Batch 1:  cost is:  6.35261e-05
# accuracy is:  0.747
# Epoch 44, CIFAR-10 Batch 2:  cost is:  0.0011746
# accuracy is:  0.7246
# Epoch 44, CIFAR-10 Batch 3:  cost is:  0.00137961
# accuracy is:  0.7392
# Epoch 44, CIFAR-10 Batch 4:  cost is:  0.00121266
# accuracy is:  0.7556
# Epoch 44, CIFAR-10 Batch 5:  cost is:  0.000848389
# accuracy is:  0.753
# Epoch 45, CIFAR-10 Batch 1:  cost is:  0.000261248
# accuracy is:  0.745
# Epoch 45, CIFAR-10 Batch 2:  cost is:  0.00559279
# accuracy is:  0.7428
# Epoch 45, CIFAR-10 Batch 3:  cost is:  0.000732138
# accuracy is:  0.7384
# Epoch 45, CIFAR-10 Batch 4:  cost is:  0.00052493
# accuracy is:  0.7406
# Epoch 45, CIFAR-10 Batch 5:  cost is:  0.00106545
# accuracy is:  0.7584
# Epoch 46, CIFAR-10 Batch 1:  cost is:  0.00087554
# accuracy is:  0.7424
# Epoch 46, CIFAR-10 Batch 2:  cost is:  0.0023557
# accuracy is:  0.7408
# Epoch 46, CIFAR-10 Batch 3:  cost is:  0.00187676
# accuracy is:  0.7452
# Epoch 46, CIFAR-10 Batch 4:  cost is:  0.000304625
# accuracy is:  0.75
# Epoch 46, CIFAR-10 Batch 5:  cost is:  0.000332112
# accuracy is:  0.7496
# Epoch 47, CIFAR-10 Batch 1:  cost is:  0.000201971
# accuracy is:  0.748
# Epoch 47, CIFAR-10 Batch 2:  cost is:  0.00302177
# accuracy is:  0.7442
# Epoch 47, CIFAR-10 Batch 3:  cost is:  0.00308964
# accuracy is:  0.7502
# Epoch 47, CIFAR-10 Batch 4:  cost is:  0.000318506
# accuracy is:  0.749
# Epoch 47, CIFAR-10 Batch 5:  cost is:  0.00285199
# accuracy is:  0.7378
# Epoch 48, CIFAR-10 Batch 1:  cost is:  0.000873015
# accuracy is:  0.7374
# Epoch 48, CIFAR-10 Batch 2:  cost is:  0.00127139
# accuracy is:  0.7422
# Epoch 48, CIFAR-10 Batch 3:  cost is:  0.000148635
# accuracy is:  0.7492
# Epoch 48, CIFAR-10 Batch 4:  cost is:  0.000461519
# accuracy is:  0.7526
# Epoch 48, CIFAR-10 Batch 5:  cost is:  0.000624283
# accuracy is:  0.754
# Epoch 49, CIFAR-10 Batch 1:  cost is:  0.0020614
# accuracy is:  0.7298
# Epoch 49, CIFAR-10 Batch 2:  cost is:  0.00185815
# accuracy is:  0.7386
# Epoch 49, CIFAR-10 Batch 3:  cost is:  0.0011881
# accuracy is:  0.7392
# Epoch 49, CIFAR-10 Batch 4:  cost is:  0.00942336
# accuracy is:  0.7384
# Epoch 49, CIFAR-10 Batch 5:  cost is:  4.25253e-05
# accuracy is:  0.7498
# Epoch 50, CIFAR-10 Batch 1:  cost is:  0.000738621
# accuracy is:  0.746
# Epoch 50, CIFAR-10 Batch 2:  cost is:  0.00107911
# accuracy is:  0.7392
# Epoch 50, CIFAR-10 Batch 3:  cost is:  0.000382566
# accuracy is:  0.7426
# Epoch 50, CIFAR-10 Batch 4:  cost is:  0.00145519
# accuracy is:  0.7556
# Epoch 50, CIFAR-10 Batch 5:  cost is:  0.000695097
# accuracy is:  0.7528
# Epoch 51, CIFAR-10 Batch 1:  cost is:  7.70068e-06
# accuracy is:  0.7568
# Epoch 51, CIFAR-10 Batch 2:  cost is:  0.00117032
# accuracy is:  0.7374
# Epoch 51, CIFAR-10 Batch 3:  cost is:  0.000676028
# accuracy is:  0.7356
# Epoch 51, CIFAR-10 Batch 4:  cost is:  0.00284088
# accuracy is:  0.7514
# Epoch 51, CIFAR-10 Batch 5:  cost is:  0.00102836
# accuracy is:  0.7518
# Epoch 52, CIFAR-10 Batch 1:  cost is:  0.000159309
# accuracy is:  0.75
# Epoch 52, CIFAR-10 Batch 2:  cost is:  0.000421008
# accuracy is:  0.7426
# Epoch 52, CIFAR-10 Batch 3:  cost is:  0.00110852
# accuracy is:  0.7284
# Epoch 52, CIFAR-10 Batch 4:  cost is:  0.00144317
# accuracy is:  0.7446
# Epoch 52, CIFAR-10 Batch 5:  cost is:  0.00194893
# accuracy is:  0.7596
# Epoch 53, CIFAR-10 Batch 1:  cost is:  0.00117645
# accuracy is:  0.7528
# Epoch 53, CIFAR-10 Batch 2:  cost is:  0.00303846
# accuracy is:  0.7418
# Epoch 53, CIFAR-10 Batch 3:  cost is:  0.000796562
# accuracy is:  0.7402
# Epoch 53, CIFAR-10 Batch 4:  cost is:  0.00274026
# accuracy is:  0.747
# Epoch 53, CIFAR-10 Batch 5:  cost is:  0.000196726
# accuracy is:  0.755
# Epoch 54, CIFAR-10 Batch 1:  cost is:  0.000182577
# accuracy is:  0.748
# Epoch 54, CIFAR-10 Batch 2:  cost is:  0.00879338
# accuracy is:  0.7374
# Epoch 54, CIFAR-10 Batch 3:  cost is:  0.00118744
# accuracy is:  0.7434
# Epoch 54, CIFAR-10 Batch 4:  cost is:  0.000439362
# accuracy is:  0.7464
# Epoch 54, CIFAR-10 Batch 5:  cost is:  0.000146681
# accuracy is:  0.7496
# Epoch 55, CIFAR-10 Batch 1:  cost is:  1.78671e-05
# accuracy is:  0.7554
# Epoch 55, CIFAR-10 Batch 2:  cost is:  0.000908788
# accuracy is:  0.7358
# Epoch 55, CIFAR-10 Batch 3:  cost is:  0.000331961
# accuracy is:  0.7406
# Epoch 55, CIFAR-10 Batch 4:  cost is:  0.000405737
# accuracy is:  0.7548
# Epoch 55, CIFAR-10 Batch 5:  cost is:  0.000454436
# accuracy is:  0.739
# Epoch 56, CIFAR-10 Batch 1:  cost is:  0.000117074
# accuracy is:  0.7398
# Epoch 56, CIFAR-10 Batch 2:  cost is:  0.000182591
# accuracy is:  0.7516
# Epoch 56, CIFAR-10 Batch 3:  cost is:  0.000132559
# accuracy is:  0.747
# Epoch 56, CIFAR-10 Batch 4:  cost is:  0.000424156
# accuracy is:  0.762
# Epoch 56, CIFAR-10 Batch 5:  cost is:  9.56288e-05
# accuracy is:  0.757
# Epoch 57, CIFAR-10 Batch 1:  cost is:  0.00165486
# accuracy is:  0.7528
# Epoch 57, CIFAR-10 Batch 2:  cost is:  0.00336508
# accuracy is:  0.7448
# Epoch 57, CIFAR-10 Batch 3:  cost is:  0.00490967
# accuracy is:  0.756
# Epoch 57, CIFAR-10 Batch 4:  cost is:  0.0016719
# accuracy is:  0.7488
# Epoch 57, CIFAR-10 Batch 5:  cost is:  2.48732e-05
# accuracy is:  0.7476
# Epoch 58, CIFAR-10 Batch 1:  cost is:  7.54521e-05
# accuracy is:  0.7402
# Epoch 58, CIFAR-10 Batch 2:  cost is:  0.00807409
# accuracy is:  0.7522
# Epoch 58, CIFAR-10 Batch 3:  cost is:  0.000523608
# accuracy is:  0.744
# Epoch 58, CIFAR-10 Batch 4:  cost is:  0.000525028
# accuracy is:  0.7508
# Epoch 58, CIFAR-10 Batch 5:  cost is:  6.95563e-05
# accuracy is:  0.7494
# Epoch 59, CIFAR-10 Batch 1:  cost is:  2.77846e-05
# accuracy is:  0.7496
# Epoch 59, CIFAR-10 Batch 2:  cost is:  0.000631421
# accuracy is:  0.7526
# Epoch 59, CIFAR-10 Batch 3:  cost is:  0.000409087
# accuracy is:  0.7444
# Epoch 59, CIFAR-10 Batch 4:  cost is:  0.00126816
# accuracy is:  0.754
# Epoch 59, CIFAR-10 Batch 5:  cost is:  0.000209323
# accuracy is:  0.7552
# Epoch 60, CIFAR-10 Batch 1:  cost is:  0.000848251
# accuracy is:  0.7436
# Epoch 60, CIFAR-10 Batch 2:  cost is:  0.00135531
# accuracy is:  0.756
# Epoch 60, CIFAR-10 Batch 3:  cost is:  0.00116976
# accuracy is:  0.7498
# Epoch 60, CIFAR-10 Batch 4:  cost is:  0.000762989
# accuracy is:  0.7534
# Epoch 60, CIFAR-10 Batch 5:  cost is:  0.00341522
# accuracy is:  0.7432
# Epoch 61, CIFAR-10 Batch 1:  cost is:  0.000966383
# accuracy is:  0.7506
# Epoch 61, CIFAR-10 Batch 2:  cost is:  0.00112347
# accuracy is:  0.7518
# Epoch 61, CIFAR-10 Batch 3:  cost is:  0.000157374
# accuracy is:  0.752
# Epoch 61, CIFAR-10 Batch 4:  cost is:  0.000275523
# accuracy is:  0.757
# Epoch 61, CIFAR-10 Batch 5:  cost is:  0.00346018
# accuracy is:  0.7492
# Epoch 62, CIFAR-10 Batch 1:  cost is:  0.000400082
# accuracy is:  0.7384
# Epoch 62, CIFAR-10 Batch 2:  cost is:  0.000674138
# accuracy is:  0.753
# Epoch 62, CIFAR-10 Batch 3:  cost is:  0.000244433
# accuracy is:  0.7442
# Epoch 62, CIFAR-10 Batch 4:  cost is:  9.69422e-06
# accuracy is:  0.7552
# Epoch 62, CIFAR-10 Batch 5:  cost is:  0.000594529
# accuracy is:  0.7522
# Epoch 63, CIFAR-10 Batch 1:  cost is:  1.93634e-05
# accuracy is:  0.75
# Epoch 63, CIFAR-10 Batch 2:  cost is:  0.00562679
# accuracy is:  0.7448
# Epoch 63, CIFAR-10 Batch 3:  cost is:  5.19267e-05
# accuracy is:  0.742
# Epoch 63, CIFAR-10 Batch 4:  cost is:  7.65193e-05
# accuracy is:  0.75
# Epoch 63, CIFAR-10 Batch 5:  cost is:  4.3506e-05
# accuracy is:  0.7468
# Epoch 64, CIFAR-10 Batch 1:  cost is:  6.01927e-05
# accuracy is:  0.7512
# Epoch 64, CIFAR-10 Batch 2:  cost is:  0.00432434
# accuracy is:  0.752
# Epoch 64, CIFAR-10 Batch 3:  cost is:  0.00324523
# accuracy is:  0.7466
# Epoch 64, CIFAR-10 Batch 4:  cost is:  0.00140521
# accuracy is:  0.7578
# Epoch 64, CIFAR-10 Batch 5:  cost is:  0.000328799
# accuracy is:  0.7548
# Epoch 65, CIFAR-10 Batch 1:  cost is:  1.98127e-05
# accuracy is:  0.75
# Epoch 65, CIFAR-10 Batch 2:  cost is:  0.000123897
# accuracy is:  0.756
# Epoch 65, CIFAR-10 Batch 3:  cost is:  5.75751e-05
# accuracy is:  0.7498
# Epoch 65, CIFAR-10 Batch 4:  cost is:  0.000477867
# accuracy is:  0.7542
# Epoch 65, CIFAR-10 Batch 5:  cost is:  0.000382734
# accuracy is:  0.7516
# Epoch 66, CIFAR-10 Batch 1:  cost is:  5.14095e-05
# accuracy is:  0.7488
# Epoch 66, CIFAR-10 Batch 2:  cost is:  0.00124557
# accuracy is:  0.7536
# Epoch 66, CIFAR-10 Batch 3:  cost is:  0.000529548
# accuracy is:  0.7586
# Epoch 66, CIFAR-10 Batch 4:  cost is:  0.000639326
# accuracy is:  0.7462
# Epoch 66, CIFAR-10 Batch 5:  cost is:  0.000239845
# accuracy is:  0.7478
# Epoch 67, CIFAR-10 Batch 1:  cost is:  2.55795e-05
# accuracy is:  0.7484
# Epoch 67, CIFAR-10 Batch 2:  cost is:  0.00220175
# accuracy is:  0.7496
# Epoch 67, CIFAR-10 Batch 3:  cost is:  0.00035476
# accuracy is:  0.7446
# Epoch 67, CIFAR-10 Batch 4:  cost is:  0.000200177
# accuracy is:  0.7562
# Epoch 67, CIFAR-10 Batch 5:  cost is:  0.000211377
# accuracy is:  0.7542
# Epoch 68, CIFAR-10 Batch 1:  cost is:  0.000881171
# accuracy is:  0.7512
# Epoch 68, CIFAR-10 Batch 2:  cost is:  0.00416892
# accuracy is:  0.7626
# Epoch 68, CIFAR-10 Batch 3:  cost is:  0.0026068
# accuracy is:  0.7482
# Epoch 68, CIFAR-10 Batch 4:  cost is:  0.00257974
# accuracy is:  0.7554
# Epoch 68, CIFAR-10 Batch 5:  cost is:  0.00022091
# accuracy is:  0.766
# Epoch 69, CIFAR-10 Batch 1:  cost is:  2.94301e-05
# accuracy is:  0.7612
# Epoch 69, CIFAR-10 Batch 2:  cost is:  0.000823965
# accuracy is:  0.7552
# Epoch 69, CIFAR-10 Batch 3:  cost is:  0.00178121
# accuracy is:  0.7618
# Epoch 69, CIFAR-10 Batch 4:  cost is:  0.00336419
# accuracy is:  0.7538
# Epoch 69, CIFAR-10 Batch 5:  cost is:  0.00681221
# accuracy is:  0.7544
# Epoch 70, CIFAR-10 Batch 1:  cost is:  1.17026e-05
# accuracy is:  0.7454
# Epoch 70, CIFAR-10 Batch 2:  cost is:  0.00157636
# accuracy is:  0.7434
# Epoch 70, CIFAR-10 Batch 3:  cost is:  3.22275e-05
# accuracy is:  0.7582
# Epoch 70, CIFAR-10 Batch 4:  cost is:  0.000345603
# accuracy is:  0.7504
# Epoch 70, CIFAR-10 Batch 5:  cost is:  0.00133511
# accuracy is:  0.754
# Epoch 71, CIFAR-10 Batch 1:  cost is:  0.00211136
# accuracy is:  0.7534
# Epoch 71, CIFAR-10 Batch 2:  cost is:  0.000174948
# accuracy is:  0.7456
# Epoch 71, CIFAR-10 Batch 3:  cost is:  8.94581e-06
# accuracy is:  0.7448
# Epoch 71, CIFAR-10 Batch 4:  cost is:  0.000119783
# accuracy is:  0.7486
# Epoch 71, CIFAR-10 Batch 5:  cost is:  0.000623821
# accuracy is:  0.7568
# Epoch 72, CIFAR-10 Batch 1:  cost is:  0.000625435
# accuracy is:  0.7472
# Epoch 72, CIFAR-10 Batch 2:  cost is:  2.24734e-05
# accuracy is:  0.7586
# Epoch 72, CIFAR-10 Batch 3:  cost is:  0.000597667
# accuracy is:  0.7408
# Epoch 72, CIFAR-10 Batch 4:  cost is:  0.000179047
# accuracy is:  0.7536
# Epoch 72, CIFAR-10 Batch 5:  cost is:  8.41116e-05
# accuracy is:  0.7584
# Epoch 73, CIFAR-10 Batch 1:  cost is:  0.000513096
# accuracy is:  0.7558
# Epoch 73, CIFAR-10 Batch 2:  cost is:  0.00013229
# accuracy is:  0.7476
# Epoch 73, CIFAR-10 Batch 3:  cost is:  2.23873e-05
# accuracy is:  0.7428
# Epoch 73, CIFAR-10 Batch 4:  cost is:  0.00117656
# accuracy is:  0.7534
# Epoch 73, CIFAR-10 Batch 5:  cost is:  0.00565302
# accuracy is:  0.7498
# Epoch 74, CIFAR-10 Batch 1:  cost is:  3.53282e-05
# accuracy is:  0.7548
# Epoch 74, CIFAR-10 Batch 2:  cost is:  6.41271e-05
# accuracy is:  0.7522
# Epoch 74, CIFAR-10 Batch 3:  cost is:  0.00191817
# accuracy is:  0.75
# Epoch 74, CIFAR-10 Batch 4:  cost is:  0.000376918
# accuracy is:  0.7512
# Epoch 74, CIFAR-10 Batch 5:  cost is:  0.00310828
# accuracy is:  0.7498
# Epoch 75, CIFAR-10 Batch 1:  cost is:  8.93014e-05
# accuracy is:  0.7542
# Epoch 75, CIFAR-10 Batch 2:  cost is:  4.35682e-06
# accuracy is:  0.7522
# Epoch 75, CIFAR-10 Batch 3:  cost is:  1.8302e-05
# accuracy is:  0.7578
# Epoch 75, CIFAR-10 Batch 4:  cost is:  0.00606001
# accuracy is:  0.7568
# Epoch 75, CIFAR-10 Batch 5:  cost is:  0.000887695
# accuracy is:  0.7558
# Epoch 76, CIFAR-10 Batch 1:  cost is:  0.000458029
# accuracy is:  0.749
# Epoch 76, CIFAR-10 Batch 2:  cost is:  0.000302823
# accuracy is:  0.7454
# Epoch 76, CIFAR-10 Batch 3:  cost is:  0.00022205
# accuracy is:  0.7474
# Epoch 76, CIFAR-10 Batch 4:  cost is:  0.000639421
# accuracy is:  0.7474
# Epoch 76, CIFAR-10 Batch 5:  cost is:  0.00398287
# accuracy is:  0.7534
# Epoch 77, CIFAR-10 Batch 1:  cost is:  0.00404761
# accuracy is:  0.7524
# Epoch 77, CIFAR-10 Batch 2:  cost is:  7.42062e-05
# accuracy is:  0.7602
# Epoch 77, CIFAR-10 Batch 3:  cost is:  0.00062786
# accuracy is:  0.7598
# Epoch 77, CIFAR-10 Batch 4:  cost is:  0.0264895
# accuracy is:  0.7574
# Epoch 77, CIFAR-10 Batch 5:  cost is:  0.000658819
# accuracy is:  0.7482
# Epoch 78, CIFAR-10 Batch 1:  cost is:  2.9146e-05
# accuracy is:  0.7488
# Epoch 78, CIFAR-10 Batch 2:  cost is:  7.7446e-06
# accuracy is:  0.7516
# Epoch 78, CIFAR-10 Batch 3:  cost is:  0.00213926
# accuracy is:  0.747
# Epoch 78, CIFAR-10 Batch 4:  cost is:  0.00291618
# accuracy is:  0.7608
# Epoch 78, CIFAR-10 Batch 5:  cost is:  0.00368971
# accuracy is:  0.7612
# Epoch 79, CIFAR-10 Batch 1:  cost is:  0.00647445
# accuracy is:  0.7416
# Epoch 79, CIFAR-10 Batch 2:  cost is:  0.00333622
# accuracy is:  0.7448
# Epoch 79, CIFAR-10 Batch 3:  cost is:  3.51912e-05
# accuracy is:  0.7584
# Epoch 79, CIFAR-10 Batch 4:  cost is:  0.00239012
# accuracy is:  0.7574
# Epoch 79, CIFAR-10 Batch 5:  cost is:  0.000533628
# accuracy is:  0.761
# Epoch 80, CIFAR-10 Batch 1:  cost is:  0.000114504
# accuracy is:  0.7498
# Epoch 80, CIFAR-10 Batch 2:  cost is:  0.00289717
# accuracy is:  0.7528
# Epoch 80, CIFAR-10 Batch 3:  cost is:  0.00107457
# accuracy is:  0.7598
# Epoch 80, CIFAR-10 Batch 4:  cost is:  0.0053249
# accuracy is:  0.7544
# Epoch 80, CIFAR-10 Batch 5:  cost is:  8.36504e-05
# accuracy is:  0.7586
# Epoch 81, CIFAR-10 Batch 1:  cost is:  0.000163844
# accuracy is:  0.7518
# Epoch 81, CIFAR-10 Batch 2:  cost is:  0.00116622
# accuracy is:  0.7526
# Epoch 81, CIFAR-10 Batch 3:  cost is:  6.83928e-05
# accuracy is:  0.7492
# Epoch 81, CIFAR-10 Batch 4:  cost is:  0.00172092
# accuracy is:  0.7634
# Epoch 81, CIFAR-10 Batch 5:  cost is:  0.00416236
# accuracy is:  0.7548
# Epoch 82, CIFAR-10 Batch 1:  cost is:  0.00024581
# accuracy is:  0.7578
# Epoch 82, CIFAR-10 Batch 2:  cost is:  0.000109775
# accuracy is:  0.7538
# Epoch 82, CIFAR-10 Batch 3:  cost is:  2.69409e-06
# accuracy is:  0.763
# Epoch 82, CIFAR-10 Batch 4:  cost is:  0.000447411
# accuracy is:  0.755
# Epoch 82, CIFAR-10 Batch 5:  cost is:  0.00111462
# accuracy is:  0.7578
# Epoch 83, CIFAR-10 Batch 1:  cost is:  0.000650512
# accuracy is:  0.7604
# Epoch 83, CIFAR-10 Batch 2:  cost is:  0.000442894
# accuracy is:  0.758
# Epoch 83, CIFAR-10 Batch 3:  cost is:  0.000354397
# accuracy is:  0.7472
# Epoch 83, CIFAR-10 Batch 4:  cost is:  0.000510294
# accuracy is:  0.7492
# Epoch 83, CIFAR-10 Batch 5:  cost is:  9.15702e-05
# accuracy is:  0.7526
# Epoch 84, CIFAR-10 Batch 1:  cost is:  0.00303351
# accuracy is:  0.7492
# Epoch 84, CIFAR-10 Batch 2:  cost is:  0.000257386
# accuracy is:  0.7582
# Epoch 84, CIFAR-10 Batch 3:  cost is:  0.00495009
# accuracy is:  0.765
# Epoch 84, CIFAR-10 Batch 4:  cost is:  0.00292294
# accuracy is:  0.7552
# Epoch 84, CIFAR-10 Batch 5:  cost is:  0.000472743
# accuracy is:  0.7666
# Epoch 85, CIFAR-10 Batch 1:  cost is:  9.35331e-05
# accuracy is:  0.7636
# Epoch 85, CIFAR-10 Batch 2:  cost is:  0.000321365
# accuracy is:  0.7466
# Epoch 85, CIFAR-10 Batch 3:  cost is:  0.000113479
# accuracy is:  0.7622
# Epoch 85, CIFAR-10 Batch 4:  cost is:  3.57332e-05
# accuracy is:  0.7536
# Epoch 85, CIFAR-10 Batch 5:  cost is:  0.0014422
# accuracy is:  0.7554
# Epoch 86, CIFAR-10 Batch 1:  cost is:  0.000727683
# accuracy is:  0.7546
# Epoch 86, CIFAR-10 Batch 2:  cost is:  0.000318588
# accuracy is:  0.7562
# Epoch 86, CIFAR-10 Batch 3:  cost is:  0.000371932
# accuracy is:  0.7518
# Epoch 86, CIFAR-10 Batch 4:  cost is:  3.42873e-05
# accuracy is:  0.7632
# Epoch 86, CIFAR-10 Batch 5:  cost is:  0.000147638
# accuracy is:  0.7588
# Epoch 87, CIFAR-10 Batch 1:  cost is:  0.00612934
# accuracy is:  0.7626
# Epoch 87, CIFAR-10 Batch 2:  cost is:  4.23192e-07
# accuracy is:  0.7686
# Epoch 87, CIFAR-10 Batch 3:  cost is:  7.30605e-05
# accuracy is:  0.7572
# Epoch 87, CIFAR-10 Batch 4:  cost is:  0.000739684
# accuracy is:  0.7612
# Epoch 87, CIFAR-10 Batch 5:  cost is:  0.000189756
# accuracy is:  0.752
# Epoch 88, CIFAR-10 Batch 1:  cost is:  0.00102788
# accuracy is:  0.755
# Epoch 88, CIFAR-10 Batch 2:  cost is:  6.05427e-05
# accuracy is:  0.7544
# Epoch 88, CIFAR-10 Batch 3:  cost is:  0.000230288
# accuracy is:  0.7624
# Epoch 88, CIFAR-10 Batch 4:  cost is:  1.53003e-05
# accuracy is:  0.7544
# Epoch 88, CIFAR-10 Batch 5:  cost is:  0.000447789
# accuracy is:  0.75
# Epoch 89, CIFAR-10 Batch 1:  cost is:  0.000137741
# accuracy is:  0.7638
# Epoch 89, CIFAR-10 Batch 2:  cost is:  2.69706e-06
# accuracy is:  0.7462
# Epoch 89, CIFAR-10 Batch 3:  cost is:  6.26278e-05
# accuracy is:  0.7436
# Epoch 89, CIFAR-10 Batch 4:  cost is:  2.5284e-05
# accuracy is:  0.7524
# Epoch 89, CIFAR-10 Batch 5:  cost is:  0.000700977
# accuracy is:  0.7586
# Epoch 90, CIFAR-10 Batch 1:  cost is:  0.00124749
# accuracy is:  0.751
# Epoch 90, CIFAR-10 Batch 2:  cost is:  7.16127e-06
# accuracy is:  0.7592
# Epoch 90, CIFAR-10 Batch 3:  cost is:  0.000297321
# accuracy is:  0.7532
# Epoch 90, CIFAR-10 Batch 4:  cost is:  0.000431792
# accuracy is:  0.7608
# Epoch 90, CIFAR-10 Batch 5:  cost is:  0.000448184
# accuracy is:  0.7458
# Epoch 91, CIFAR-10 Batch 1:  cost is:  0.00231498
# accuracy is:  0.7464
# Epoch 91, CIFAR-10 Batch 2:  cost is:  0.000152565
# accuracy is:  0.7564
# Epoch 91, CIFAR-10 Batch 3:  cost is:  0.000476183
# accuracy is:  0.7538
# Epoch 91, CIFAR-10 Batch 4:  cost is:  1.67103e-05
# accuracy is:  0.7626
# Epoch 91, CIFAR-10 Batch 5:  cost is:  0.000145386
# accuracy is:  0.7596
# Epoch 92, CIFAR-10 Batch 1:  cost is:  0.00239074
# accuracy is:  0.7588
# Epoch 92, CIFAR-10 Batch 2:  cost is:  2.38555e-05
# accuracy is:  0.7592
# Epoch 92, CIFAR-10 Batch 3:  cost is:  0.000394109
# accuracy is:  0.7572
# Epoch 92, CIFAR-10 Batch 4:  cost is:  6.14227e-05
# accuracy is:  0.7526
# Epoch 92, CIFAR-10 Batch 5:  cost is:  4.33363e-05
# accuracy is:  0.7646
# Epoch 93, CIFAR-10 Batch 1:  cost is:  0.00093363
# accuracy is:  0.7566
# Epoch 93, CIFAR-10 Batch 2:  cost is:  4.65442e-05
# accuracy is:  0.7456
# Epoch 93, CIFAR-10 Batch 3:  cost is:  0.00143158
# accuracy is:  0.758
# Epoch 93, CIFAR-10 Batch 4:  cost is:  9.54214e-06
# accuracy is:  0.758
# Epoch 93, CIFAR-10 Batch 5:  cost is:  0.000290697
# accuracy is:  0.7552
# Epoch 94, CIFAR-10 Batch 1:  cost is:  0.0025532
# accuracy is:  0.759
# Epoch 94, CIFAR-10 Batch 2:  cost is:  0.000715818
# accuracy is:  0.762
# Epoch 94, CIFAR-10 Batch 3:  cost is:  2.27003e-05
# accuracy is:  0.7642
# Epoch 94, CIFAR-10 Batch 4:  cost is:  0.000587466
# accuracy is:  0.7596
# Epoch 94, CIFAR-10 Batch 5:  cost is:  0.00514044
# accuracy is:  0.7626
# Epoch 95, CIFAR-10 Batch 1:  cost is:  0.00314507
# accuracy is:  0.7554
# Epoch 95, CIFAR-10 Batch 2:  cost is:  1.97666e-05
# accuracy is:  0.7512
# Epoch 95, CIFAR-10 Batch 3:  cost is:  1.39046e-05
# accuracy is:  0.7622
# Epoch 95, CIFAR-10 Batch 4:  cost is:  0.00132234
# accuracy is:  0.7534
# Epoch 95, CIFAR-10 Batch 5:  cost is:  0.000175342
# accuracy is:  0.7596
# Epoch 96, CIFAR-10 Batch 1:  cost is:  5.26486e-05
# accuracy is:  0.762
# Epoch 96, CIFAR-10 Batch 2:  cost is:  0.000117937
# accuracy is:  0.7592
# Epoch 96, CIFAR-10 Batch 3:  cost is:  5.95701e-05
# accuracy is:  0.7614
# Epoch 96, CIFAR-10 Batch 4:  cost is:  0.000158031
# accuracy is:  0.7634
# Epoch 96, CIFAR-10 Batch 5:  cost is:  0.000525496
# accuracy is:  0.7474
# Epoch 97, CIFAR-10 Batch 1:  cost is:  0.000838837
# accuracy is:  0.7634
# Epoch 97, CIFAR-10 Batch 2:  cost is:  3.8324e-06
# accuracy is:  0.755
# Epoch 97, CIFAR-10 Batch 3:  cost is:  0.00171398
# accuracy is:  0.762
# Epoch 97, CIFAR-10 Batch 4:  cost is:  6.96799e-05
# accuracy is:  0.7618
# Epoch 97, CIFAR-10 Batch 5:  cost is:  0.000100836
# accuracy is:  0.7562
# Epoch 98, CIFAR-10 Batch 1:  cost is:  0.00060866
# accuracy is:  0.7686
# Epoch 98, CIFAR-10 Batch 2:  cost is:  0.000444887
# accuracy is:  0.7584
# Epoch 98, CIFAR-10 Batch 3:  cost is:  0.000772538
# accuracy is:  0.7588
# Epoch 98, CIFAR-10 Batch 4:  cost is:  4.78011e-06
# accuracy is:  0.7692
# Epoch 98, CIFAR-10 Batch 5:  cost is:  0.000604017
# accuracy is:  0.759
# Epoch 99, CIFAR-10 Batch 1:  cost is:  0.00181809
# accuracy is:  0.7584
# Epoch 99, CIFAR-10 Batch 2:  cost is:  1.66957e-05
# accuracy is:  0.766
# Epoch 99, CIFAR-10 Batch 3:  cost is:  3.25735e-06
# accuracy is:  0.7608
# Epoch 99, CIFAR-10 Batch 4:  cost is:  0.00815399
# accuracy is:  0.7588
# Epoch 99, CIFAR-10 Batch 5:  cost is:  9.574e-05
# accuracy is:  0.7564
# Epoch 100, CIFAR-10 Batch 1:  cost is:  9.95392e-07
# accuracy is:  0.7508
# Epoch 100, CIFAR-10 Batch 2:  cost is:  0.000204803
# accuracy is:  0.765
# Epoch 100, CIFAR-10 Batch 3:  cost is:  0.000332441
# accuracy is:  0.7612
# Epoch 100, CIFAR-10 Batch 4:  cost is:  0.000157938
# accuracy is:  0.7642
# Epoch 100, CIFAR-10 Batch 5:  cost is:  0.000761029
# accuracy is:  0.7536

# %% [markdown]
# # 检查点
#
# 模型已保存到本地。
#
# ## 测试模型
#
# 利用测试数据集测试你的模型。这将是最终的准确率。你的准确率应该高于 50%。如果没达到，请继续调整模型结构和参数。

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import tensorflow as tf
import pickle
import helper
import random

# Set batch size if not already set
try:
    if batch_size:
        pass
except NameError:
    batch_size = 64

save_model_path = './image_classification'
n_samples = 4
top_n_predictions = 3

def test_model():
    """
    Test the saved model against the test dataset
    """

    test_features, test_labels = pickle.load(open('preprocess_test.p', mode='rb'))
    loaded_graph = tf.Graph()

    with tf.Session(graph=loaded_graph) as sess:
        # Load model
        loader = tf.train.import_meta_graph(save_model_path + '.meta')
        loader.restore(sess, save_model_path)

        # Get Tensors from loaded model
        loaded_x = loaded_graph.get_tensor_by_name('x:0')
        loaded_y = loaded_graph.get_tensor_by_name('y:0')
        loaded_keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')
        loaded_logits = loaded_graph.get_tensor_by_name('logits:0')
        loaded_acc = loaded_graph.get_tensor_by_name('accuracy:0')
        
        # Get accuracy in batches for memory limitations
        test_batch_acc_total = 0
        test_batch_count = 0
        
        for test_feature_batch, test_label_batch in helper.batch_features_labels(test_features, test_labels, batch_size):
            test_batch_acc_total += sess.run(
                loaded_acc,
                feed_dict={loaded_x: test_feature_batch, loaded_y: test_label_batch, loaded_keep_prob: 1.0})
            test_batch_count += 1

        print('Testing Accuracy: {}\n'.format(test_batch_acc_total/test_batch_count))

        # Print Random Samples
        random_test_features, random_test_labels = tuple(zip(*random.sample(list(zip(test_features, test_labels)), n_samples)))
        random_test_predictions = sess.run(
            tf.nn.top_k(tf.nn.softmax(loaded_logits), top_n_predictions),
            feed_dict={loaded_x: random_test_features, loaded_y: random_test_labels, loaded_keep_prob: 1.0})
        helper.display_image_predictions(random_test_features, random_test_labels, random_test_predictions)


test_model()
# Out:
# Testing Accuracy: 0.7534612341772152

# %% [markdown]
# ## 为何准确率只有50-80%？
#
# 你可能想问，为何准确率不能更高了？首先，对于简单的 CNN 网络来说，50% 已经不低了。纯粹猜测的准确率为10%。但是，你可能注意到有人的准确率[远远超过 80%](http://rodrigob.github.io/are_we_there_yet/build/classification_datasets_results.html#43494641522d3130)。这是因为我们还没有介绍所有的神经网络知识。我们还需要掌握一些其他技巧。
#
# ## 提交项目
#
# 提交项目时，确保先运行所有单元，然后再保存记事本。将 notebook 文件另存为“dlnd_image_classification.ipynb”，再在目录 "File" -> "Download as" 另存为 HTML 格式。请在提交的项目中包含 “helper.py” 和 “problem_unittests.py” 文件。
